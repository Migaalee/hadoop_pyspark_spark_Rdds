# %% [markdown]
# <a href="https://colab.research.google.com/github/Migaalee/hadoop/blob/main/Copy_of_mapreduce_week1_word_frequency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python MapReduce Exercise
#
# In the notebook, you should create a map-reduce program that count the number of occurrence of each word.
#
# In this exercise, hadoop runs in standalone mode and reads data from the local filesystem.

# %% [markdown]
# ### Download the dataset

# %%
# !wget -O os_maias.txt https://www.dropbox.com/s/n24v0z7y79np319/os_maias.txt?dl=0
# Out:
# --2020-10-02 18:49:15--  https://www.dropbox.com/s/n24v0z7y79np319/os_maias.txt?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.68.1, 2620:100:6024:1::a27d:4401
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.68.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/n24v0z7y79np319/os_maias.txt [following]
# --2020-10-02 18:49:16--  https://www.dropbox.com/s/raw/n24v0z7y79np319/os_maias.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce02e56f85dd07a849545c3e633.dl.dropboxusercontent.com/cd/0/inline/BAjdG-vVqAWvj01J4DduV6-_kfeT71HNCKz1ho7mKII8cKPfb9qwtEOLxlFbAy2WTuikkUji_q2_KWiqubawgSFriqy_1PNF6DUVsKxMPXN5Zw/file# [following]
# --2020-10-02 18:49:16--  https://uce02e56f85dd07a849545c3e633.dl.dropboxusercontent.com/cd/0/inline/BAjdG-vVqAWvj01J4DduV6-_kfeT71HNCKz1ho7mKII8cKPfb9qwtEOLxlFbAy2WTuikkUji_q2_KWiqubawgSFriqy_1PNF6DUVsKxMPXN5Zw/file
# Resolving uce02e56f85dd07a849545c3e633.dl.dropboxusercontent.com (uce02e56f85dd07a849545c3e633.dl.dropboxusercontent.com)... 162.125.68.15, 2620:100:6024:15::a27d:440f
# Connecting to uce02e56f85dd07a849545c3e633.dl.dropboxusercontent.com (uce02e56f85dd07a849545c3e633.dl.dropboxusercontent.com)|162.125.68.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1292368 (1.2M) [text/plain]
# Saving to: ‘os_maias.txt’
#
# os_maias.txt        100%[===================>]   1.23M  5.43MB/s    in 0.2s
#
# 2020-10-02 18:49:17 (5.43 MB/s) - ‘os_maias.txt’ saved [1292368/1292368]

# %% [markdown]
# ## WordCount Example
# Read the words from input and count the number of occurrences of each word.

# %% [markdown]
# ### Mapper
# Complete with the code for the mapper.

# %%
# %%file mapper_words.py
#!/usr/bin/env python


# import sys
import sys
# import string library function  
import string  

# input comes from STDIN (standard input)
for line in sys.stdin:
    # remove leading and trailing whitespace
    line = line.strip()
    # remove punctuation characters
    line = line.translate(str.maketrans('', '', string.punctuation+'«»'))
    # split the line into words
    words = line.split()
    for w in words:
        print('%s\t%s' % (w,"1"))
# Out:
# Overwriting mapper_words.py

# %% [markdown]
# ### Reducer

# %%
# %%file reducer_words.py
#!/usr/bin/python

#input: w1 w2 w1 w3 w1 w3
# w1,1
# w1,1
# w1, 1
# w2, 1
# w3, 1
# w3, 1

import sys

last_word = ''
count_words = 0

# input comes from STDIN
for line in sys.stdin:
    # remove leading and trailing whitespace
    line = line.strip()

    # parse the input we got from mapper.py
    word, count = line.split('\t', 1)

    # convert count (currently a string) to int
    count = int(count)
    
    if last_word != word:
        if last_word != '':
            print ("%s\t%s" % (last_word, count_words))
        last_word = word
        count_words = count
    else:
        count_words += count
        
print ("%s\t%s" % (last_word, count_words))
# Out:
# Overwriting reducer_words.py

# %% [markdown]
# ### Hadoop standalone mode execution

# %% [markdown]
# The output directory needs to be cleared...

# %%
rm -rf results_words

# %% [markdown]
# #### Submitting the job
#
# The _hadoop_ command is used to submit the mapreduce job to the cluster...

# %%
# !hadoop jar /opt/hadoop-3.2.0/share/hadoop/tools/lib/hadoop-*streaming*.jar -files mapper_words.py,reducer_words.py -mapper mapper_words.py -reducer reducer_words.py -input os_maias.txt -output results_words
# Out:
# 2020-10-02 18:49:27,623 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2020-10-02 18:49:27,688 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2020-10-02 18:49:27,688 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2020-10-02 18:49:27,701 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2020-10-02 18:49:27,848 INFO mapred.FileInputFormat: Total input files to process : 1
# 2020-10-02 18:49:27,866 INFO mapreduce.JobSubmitter: number of splits:1
# 2020-10-02 18:49:28,010 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local2040609651_0001
# 2020-10-02 18:49:28,010 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2020-10-02 18:49:28,219 INFO mapred.LocalDistributedCacheManager: Localized file:/home/jovyan/work/mapper_words.py as file:/tmp/hadoop-jovyan/mapred/local/job_local2040609651_0001_df4d4c4c-1948-48a6-9daa-53d728ea7433/mapper_words.py
# 2020-10-02 18:49:28,247 INFO mapred.LocalDistributedCacheManager: Localized file:/home/jovyan/work/reducer_words.py as file:/tmp/hadoop-jovyan/mapred/local/job_local2040609651_0001_cc9c3e94-38d8-4f5c-b916-6e51a19b8e48/reducer_words.py
# 2020-10-02 18:49:28,299 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2020-10-02 18:49:28,301 INFO mapreduce.Job: Running job: job_local2040609651_0001
# 2020-10-02 18:49:28,306 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2020-10-02 18:49:28,307 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2020-10-02 18:49:28,310 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2020-10-02 18:49:28,310 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-10-02 18:49:28,340 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2020-10-02 18:49:28,343 INFO mapred.LocalJobRunner: Starting task: attempt_local2040609651_0001_m_000000_0
# 2020-10-02 18:49:28,374 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2020-10-02 18:49:28,375 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-10-02 18:49:28,392 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2020-10-02 18:49:28,402 INFO mapred.MapTask: Processing split: file:/home/jovyan/work/os_maias.txt:0+1292368
# 2020-10-02 18:49:28,414 INFO mapred.MapTask: numReduceTasks: 1
# 2020-10-02 18:49:28,464 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2020-10-02 18:49:28,464 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2020-10-02 18:49:28,464 INFO mapred.MapTask: soft limit at 83886080
# 2020-10-02 18:49:28,464 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2020-10-02 18:49:28,464 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2020-10-02 18:49:28,467 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2020-10-02 18:49:28,472 INFO streaming.PipeMapRed: PipeMapRed exec [/home/jovyan/work/./mapper_words.py]
# 2020-10-02 18:49:28,476 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2020-10-02 18:49:28,477 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2020-10-02 18:49:28,477 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2020-10-02 18:49:28,478 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2020-10-02 18:49:28,478 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2020-10-02 18:49:28,478 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2020-10-02 18:49:28,478 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2020-10-02 18:49:28,478 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2020-10-02 18:49:28,479 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2020-10-02 18:49:28,479 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2020-10-02 18:49:28,479 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2020-10-02 18:49:28,479 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2020-10-02 18:49:28,495 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:28,496 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:28,501 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:28,537 INFO streaming.PipeMapRed: Records R/W=532/1
# 2020-10-02 18:49:28,573 INFO streaming.PipeMapRed: R/W/S=1000/7333/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:28,918 INFO streaming.PipeMapRed: MRErrorThread done
# 2020-10-02 18:49:28,919 INFO streaming.PipeMapRed: mapRedFinished
# 2020-10-02 18:49:28,921 INFO mapred.LocalJobRunner:
# 2020-10-02 18:49:28,921 INFO mapred.MapTask: Starting flush of map output
# 2020-10-02 18:49:28,921 INFO mapred.MapTask: Spilling map output
# 2020-10-02 18:49:28,921 INFO mapred.MapTask: bufstart = 0; bufend = 1653351; bufvoid = 104857600
# 2020-10-02 18:49:28,921 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25360964(101443856); length = 853433/6553600
# 2020-10-02 18:49:29,247 INFO mapred.MapTask: Finished spill 0
# 2020-10-02 18:49:29,257 INFO mapred.Task: Task:attempt_local2040609651_0001_m_000000_0 is done. And is in the process of committing
# 2020-10-02 18:49:29,258 INFO mapred.LocalJobRunner: Records R/W=532/1
# 2020-10-02 18:49:29,259 INFO mapred.Task: Task 'attempt_local2040609651_0001_m_000000_0' done.
# 2020-10-02 18:49:29,264 INFO mapred.Task: Final Counters for attempt_local2040609651_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=1470222
# 		FILE: Number of bytes written=2778921
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=5877
# 		Map output records=213359
# 		Map output bytes=1653351
# 		Map output materialized bytes=2080075
# 		Input split bytes=87
# 		Combine input records=0
# 		Spilled Records=213359
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=204472320
# 	File Input Format Counters
# 		Bytes Read=1292368
# 2020-10-02 18:49:29,265 INFO mapred.LocalJobRunner: Finishing task: attempt_local2040609651_0001_m_000000_0
# 2020-10-02 18:49:29,265 INFO mapred.LocalJobRunner: map task executor complete.
# 2020-10-02 18:49:29,267 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2020-10-02 18:49:29,268 INFO mapred.LocalJobRunner: Starting task: attempt_local2040609651_0001_r_000000_0
# 2020-10-02 18:49:29,284 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2020-10-02 18:49:29,285 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-10-02 18:49:29,286 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2020-10-02 18:49:29,290 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@95ff2f9
# 2020-10-02 18:49:29,291 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2020-10-02 18:49:29,305 INFO mapreduce.Job: Job job_local2040609651_0001 running in uber mode : false
# 2020-10-02 18:49:29,306 INFO mapreduce.Job:  map 100% reduce 0%
# 2020-10-02 18:49:29,317 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=325163424, maxSingleShuffleLimit=81290856, mergeThreshold=214607872, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2020-10-02 18:49:29,321 INFO reduce.EventFetcher: attempt_local2040609651_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2020-10-02 18:49:29,351 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local2040609651_0001_m_000000_0 decomp: 2080071 len: 2080075 to MEMORY
# 2020-10-02 18:49:29,360 INFO reduce.InMemoryMapOutput: Read 2080071 bytes from map-output for attempt_local2040609651_0001_m_000000_0
# 2020-10-02 18:49:29,362 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 2080071, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->2080071
# 2020-10-02 18:49:29,366 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2020-10-02 18:49:29,367 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2020-10-02 18:49:29,367 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2020-10-02 18:49:29,373 INFO mapred.Merger: Merging 1 sorted segments
# 2020-10-02 18:49:29,373 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 2080067 bytes
# 2020-10-02 18:49:29,506 INFO reduce.MergeManagerImpl: Merged 1 segments, 2080071 bytes to disk to satisfy reduce memory limit
# 2020-10-02 18:49:29,507 INFO reduce.MergeManagerImpl: Merging 1 files, 2080075 bytes from disk
# 2020-10-02 18:49:29,508 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2020-10-02 18:49:29,508 INFO mapred.Merger: Merging 1 sorted segments
# 2020-10-02 18:49:29,509 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 2080067 bytes
# 2020-10-02 18:49:29,510 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2020-10-02 18:49:29,513 INFO streaming.PipeMapRed: PipeMapRed exec [/home/jovyan/work/./reducer_words.py]
# 2020-10-02 18:49:29,517 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2020-10-02 18:49:29,519 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2020-10-02 18:49:29,541 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:29,541 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:29,542 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:29,548 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:29,572 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:29,593 INFO streaming.PipeMapRed: Records R/W=16574/1
# 2020-10-02 18:49:29,805 INFO streaming.PipeMapRed: R/W/S=100000/8660/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:29,979 INFO streaming.PipeMapRed: R/W/S=200000/19732/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:49:30,025 INFO streaming.PipeMapRed: MRErrorThread done
# 2020-10-02 18:49:30,027 INFO streaming.PipeMapRed: mapRedFinished
# 2020-10-02 18:49:30,028 INFO mapred.Task: Task:attempt_local2040609651_0001_r_000000_0 is done. And is in the process of committing
# 2020-10-02 18:49:30,029 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2020-10-02 18:49:30,029 INFO mapred.Task: Task attempt_local2040609651_0001_r_000000_0 is allowed to commit now
# 2020-10-02 18:49:30,030 INFO output.FileOutputCommitter: Saved output of task 'attempt_local2040609651_0001_r_000000_0' to file:/home/jovyan/work/results_words
# 2020-10-02 18:49:30,034 INFO mapred.LocalJobRunner: Records R/W=16574/1 > reduce
# 2020-10-02 18:49:30,034 INFO mapred.Task: Task 'attempt_local2040609651_0001_r_000000_0' done.
# 2020-10-02 18:49:30,035 INFO mapred.Task: Final Counters for attempt_local2040609651_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=5630404
# 		FILE: Number of bytes written=5113333
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=22673
# 		Reduce shuffle bytes=2080075
# 		Reduce input records=213359
# 		Reduce output records=22673
# 		Spilled Records=213359
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=9
# 		Total committed heap usage (bytes)=204996608
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=254337
# 2020-10-02 18:49:30,036 INFO mapred.LocalJobRunner: Finishing task: attempt_local2040609651_0001_r_000000_0
# 2020-10-02 18:49:30,036 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2020-10-02 18:49:30,310 INFO mapreduce.Job:  map 100% reduce 100%
# 2020-10-02 18:49:30,311 INFO mapreduce.Job: Job job_local2040609651_0001 completed successfully
# 2020-10-02 18:49:30,334 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=7100626
# 		FILE: Number of bytes written=7892254
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=5877
# 		Map output records=213359
# 		Map output bytes=1653351
# 		Map output materialized bytes=2080075
# 		Input split bytes=87
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=22673
# 		Reduce shuffle bytes=2080075
# 		Reduce input records=213359
# 		Reduce output records=22673
# 		Spilled Records=426718
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=9
# 		Total committed heap usage (bytes)=409468928
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read
# acorda	1
# acordada	3
# acordado	3
# acordam	1
# acordando	3
# acordar	4
# acordara	1
# acordaram	1
# acordasse	1
# acordava	3
# acordes	2
# acordo	5
# acordou	5
# acostumado	2
# acostumados	1
# acostumar	1
# acostumou	1
# acotovela	1
# acotovelandose	1
# acotovelavam	1
# acre	1
# acredita	4
# acreditam	1
# acreditar	11
# acreditaremse	1
# acreditaria	2
# acreditas	2
# acreditava	3
# acreditavam	1
# acredite	5
# acredito	1
# acreditássemos	1
# acrescentado	1
# acrescentando	1
# acrescentar	2
# acrescentara	1
# acrescentava	6
# acrescentou	36
# acrobata	2
# acta	1
# activa	3
# actividade	3
# actividades	1
# activos	2
# acto	10
# actor	1
# actos	1
# actriz	1
# actrizes	4
# acudia	2
# acudiam	2
# acudiamlhe	1
# acudira	1
# acudiu	37
# acumulado	1
# acumulados	2
# acumularao	1
# acumulavam	2
# acumulação	1
# acumulouas	1
# acusado	1
# acusar	1
# acusava	1
# acuses	1
# acusou	1
# acusouo	1
# acácias	19
# acção	5
# acções	3
# adamascada	1
# adamascado	1
# adelgaçado	1
# adelgaçarse	1
# adeus	19
# adiada	1
# adiado	1
# adiando	1
# adiantado	1
# adiantamos	1
# adiantando	3
# adiantandose	2
# adiantar	1
# adiantase	1
# adiantasse	1
# adiantavam	1
# adiante	24
# adiantou	1
# adiantouse	3
# adiar	1
# adiava	2
# adiavase	1
# adido	3
# adivinha	2
# adivinhada	1
# adivinhar	4
# adivinhara	1
# adivinhaste	1
# adivinhava	2
# adiós	1
# adjectivo	1
# administrador	20
# administrava	2
# admira	2
# admirador	1
# admiradora	1
# admiradores	1
# admiram	1
# admirando	3
# admirandoo	1
# admirar	6
# admirara	2
# admiraram	1
# admiraria	1
# admirarse	1
# admirará	1
# admirasse	1
# admirava	8
# admiravam	1
# admiravamlhe	1
# admiravelmente	3
# admiração	16
# admirações	3
# admiroulhe	1
# admiráveis	1
# admirável	4
# admissão	1
# admite	3
# admiti	1
# admitia	5
# admitido	1
# admitiu	1
# admito	2
# adocicada	2
# adocicadas	1
# adocicado	2
# adocicava	1
# adoecer	3
# adoecera	2
# adoecia	1
# adoecido	1
# adoentada	2
# adoidado	1
# adoptao	1
# adoptar	1
# adoptara	1
# adora	1
# adorada	2
# adorado	3
# adorala	1
# adorando	1
# adorar	2
# adorara	1
# adorarte	1
# adorava	7
# adoravaa	4
# adoravam	1
# adoravelmente	1
# adoração	4
# adormecendo	5
# adormecer	3
# adormecera	2
# adormeceria	1
# adormeceu	2
# adormecia	3
# adormeciam	1
# adormecida	11
# adormecidas	1
# adormecido	9
# adormecimento	2
# adormentados	1
# adornar	1
# adorno	1
# adoro	4
# adorote	1
# adorou	1
# adoráveis	2
# adorável	19
# adoçar	1
# adoçava	1
# adoçou	1
# adquiriam	1
# adquirir	1
# adresse	9
# adresses	1
# adro	3
# adros	2
# aduaneiros	1
# adulava	1
# adulteração	1
# adultero	1
# adultério	3
# adultérios	2
# adunco	1
# aduncos	1
# advento	3
# advertido	1
# advertiu	1
# advertiua	1
# tinhamlhe	2
# tinhamna	1
# tinhamno	3
# tinhamse	14
# tinhao	3
# tinhas	7
# tinhase	2
# tinhaslhe	1
# tinhate	2
# tinia	1
# tinir	3
# tinta	7
# tintas	1
# tiníamos	1
# tio	36
# tios	1
# tipa	2
# tipo	18
# tipos	3
# tiposinho	2
# tipóia	56
# tipóias	3
# tira	9
# tirabotas	1
# tiracolo	7
# tirado	2
# tirados	1
# tiragem	5
# tiram	1
# tirando	19
# tiranos	1
# tirante	1
# tirar	18
# tirara	5
# tirarlhe	1
# tirasse	3
# tirava	7
# tiravam	4
# tire	3
# tiritando	1
# tiritar	2
# tiro	3
# tirolesa	1
# tiros	2
# tirou	10
# tiroulhe	2
# tisnada	1
# tisnadas	1
# tisnado	1
# titi	22
# titular	1
# tive	16
# tivemolas	1
# tivemos	3
# tiver	1
# tivera	27
# tiveraa	1
# tiveram	3
# tiverem	1
# tivesse	44
# tivessem	1
# tiveste	2
# tivéssemos	1
# to	2
# toada	2
# toaletes	1
# toalha	11
# toalhas	1
# toca	8
# tocadas	1
# tocado	4
# tocados	1
# tocando	10
# tocandolhe	1
# tocante	4
# tocar	7
# tocara	1
# tocaralhe	1
# tocarao	1
# tocarem	1
# tocarlhe	1
# tocará	1
# tocasse	1
# tocassem	2
# tocava	13
# tocavalhe	1
# tocavam	2
# tocavase	1
# tocha	1
# tocou	9
# tocoulhe	6
# toda	268
# todas	115
# todavia	23
# todo	295
# todos	165
# toilete	20
# toiletes	6
# toiro	2
# toiros	1
# tola	1
# toldado	1
# toldo	5
# toldos	1
# tolera	2
# tolerando	1
# tolerar	1
# tolerava	3
# tolero	3
# tolerável	1
# tolhesse	1
# tolice	16
# tolices	1
# tolo	1
# tolos	1
# tom	64
# toma	2
# tomada	5
# tomado	14
# tomados	1
# tomalas	1
# tomalo	1
# tomame	1
# tomando	14
# tomandolhe	2
# tomar	33
# tomara	11
# tomaralhe	1
# tomaram	1
# tomarase	1
# tomaria	1
# tomarlhe	2
# tomas	2
# tomase	1
# tomate	2
# tomates	1
# tomava	18
# tomavalhe	1
# tomavam	6
# tomavamno	1
# tombadas	1
# tombado	2
# tombava	1
# tombou	2
# tome	3
# tomei	1
# tomem	1
# tomo	1
# tomou	24
# tomoulhe	8
# tonificação	1
# tons	27
# tonta	5
# tontas	2
# tonteira	1
# tonteria	1
# tonto	3
# tontura	1
# tonturas	2
# topada	1
# topete	2
# topo	4
# topou	2
# toque	4
# toques	1
# torcendo	5
# torceu	1
# torcia	4
# torciase	1
# tormenta	1
# tormento	6
# tormentos	2
# tormentosa	1
# torna	3
# tornadas	1
# tornado	1
# tornam	1
# tornamos	1
# tornamse	1
# tornando	10
# tornandoo	1
# tornandose	2
# tornar	13
# tornara	12
# tornaram	1
# tornaramse	1
# tornarao	1
# tornarase	8
# tornaria	3
# tornarse	2
# tornarsehia	1
# tornase	2
# tornasse	3
# tornava	10
# tornavalha	1
# tornavam	2
# tornavao	1
# tornavase	5
# torne	1
# torneada	1
# torneados	1
# tornei	3
# torneio	1
# torneios	1
# torneira	1
# torno	31
# tornou	15
# tornoulhe	1
# tornouse	3
# tornámos	1
# torpe	12
# torpedos	1
# torpemente	1
# torpes	2
# torpeza	3
# torpezas	2
# torpor	1
# torrar	2
# torrava	1
# torre	5
# torrencial	1
# torres	1
# torrãosinho	1
# torrões	1
# tort	1
# tortulho	1
# tortuosa	1
# tortura	4
# torturado	3
# torturala	1
# torturando	1
# torturandose	1
# torturante	1
# torturar	1
# torturas	1
# torturasse	1
# torturava	3
# torturavam	2
# torturoume	1
# torvelinho	1
# tory	1
# tosca	4
# toscas	1
# tosco	1
# toscos	1
# tosse	7
# tosses	1
# tossia	2
# tossiam	1
# tossir	2
# tossira	2
# tossiu	4
# tostons	1
# tostão	3
# tostões	14
# tostõesinhos	2
# total	1
# totalmente	1
# touca	4
# toucador	13
# toujours	3
# tourada	9
# toureiro	1
# touriste	2
# touristes	1
# touro	9
# touros	6
# tout	1
# toute	2
# trabalha	1
# trabalhada	2
# trabalhadas	1
# trabalhado	3
# trabalhador	2
# trabalhadores	1
# trabalhados	1
# trabalhamos	1
# trabalhar	5
# trabalhara	1
# trabalhas	1
# trabalhase	1
# trabalhasse	1
# trabalho	36
# trabalhos	6
# tradicional	1
# tradicionalmente	1
# tradição	3
# tradições	4
# traduzida	1
# traduzido	1
# traduzidos	1
# traduzir	1
# traduções	2
# traga	2
# tragame	1
# tragamno	1
# tragar	1
# tragicamente	3
# trago	8
# tragoa	1
# tragos	1
# tragou	1
# tragédia	4
# traia	2
# traidor	2
# traiçoeira	1
# traição	3
# traje	3
# trama	3
# tramada	1
# trambolho	2
# trambolhões	2
# tramóia	1
# trancas	1
# tranquila	6
# tranquilamente	19
# tranquilidade	7
# tranquilizar	3
# tranquilizasse	1
# tranquilizou	2
# tranquilizoua	1
# tranquilizouo	2
# tranquilo	12
# tranquilos	2
# transacção	2
# transbordando	4
# transbordar	2
# transbordava	4
# transbordou	1
# transcrições	1
# transe	1
# transformar	4
# transformara	1
# transformarse	1
# transformavase	1
# transformação	2
# transformações	1
# transia	1
# transido	2
# transição	3
# transluziam	1
# transmitir	1
# transmitiu	1
# transmontano	2
# transparecendo	1
# transpareceu	1
# transparecia	4
# transparente	5
# transparentes	4
# transparência	2
# transparências	1
# transpirar	1
# transportado	1
# transportando	1
# transportar	1
# transpunha	1
# transtornada	3
# transtornado	2
# transviada	1
# transviados	1
# trança	2
# tranças	7
# trapalhada	1
# trapalhadas	1
# trapalhão	2
# trapeira	2
# trapista	1
# trapo	3
# trapos	2
# trapésio	4
# trapézio	8
# traquitana	6
# trarei	1
# traria	3
# trasladado	1
# trasladar	1
# traste	4
# trata	12
# tratada	1
# tratado	3
# tratados	1
# tratalo	1
# tratamento	2
# tratamse	2
# tratando	4
# tratandoo	1
# tratandose	1
# tratar	9
# trataramse	1
# tratarme	1
# tratarse	1
# tratase	2
# tratasse	2
# tratava	9
# tratavaa	1
# tratavam	2
# tratavamse	3
# tratavao	1
# tratavase	1
# tratou	1
# tratássemos	1
# trauteando	1
# travadas	1
# travando	6
# turbulenta	1
# turco	2
# turcos	2
# turno	1
# turva	1
# turvo	2
# turvos	3
# tutelar	2
# tábua	3
# tácita	1
# táctica	2
# tãbem	1
# tão	355
# técnicos	1
# tédio	15
# tédios	1
# ténue	4
# tépida	7
# tépido	5
# térrea	1
# térreos	2
# têm	24
# têrivêl	1
# tímida	7
# tímidas	1
# tímido	9
# tímidos	2
# tínhamos	4
# típico	1
# tísico	3
# título	8
# títulos	4
# tóca	1
# túmulo	1
# túnica	1
# ufanava	1
# uivar	1
# uivava	1
# uivos	2
# ulster	5
# ultima	17
# ultimamente	16
# ultimas	10
# ultimo	20
# ultrages	1
# ultrajado	1
# ultrajante	2
# ultraje	2
# um	3026
# uma	2170
# umas	43
# umbigo	1
# umbrais	1
# un	7
# una	2
# une	5
# ungido	1
# unhas	5
# unia	1
# uniamse	1
# unicamente	5
# unida	1
# unidas	1
# unido	1
# unidos	1
# uniforme	1
# uniformes	1
# uniramse	2
# universal	1
# universo	4
# união	6
# uniões	1
# uns	47
# unânime	1
# upa	1
# urgente	5
# urgentemente	2
# urgência	1
# urro	1
# urros	3
# urso	7
# usa	2
# usado	1
# usados	1
# usando	1
# usandolhe	1
# usao	1
# usar	5
# usarem	1
# usasse	1
# usava	5
# usei	1
# uso	3
# usouo	1
# usted	2
# ustêd	2
# usual	1
# utilizar	1
# utilizo	1
# uvas	3
# v	1
# va	2
# vaca	1
# vacas	2
# vacilando	1
# vacilar	1
# vacilações	1
# vadiagem	2
# vadiando	1
# vadiar	1
# vadiava	1
# vadio	1
# vadios	3
# vaga	16
# vagamente	18
# vagar	18
# vagares	6
# vagarosa	1
# vagarosamente	7
# vagaroso	4
# vagas	3
# vago	41
# vagos	5
# vagueando	2
# vai	59
# vaidade	2
# vaidosas	1
# vaidoso	1
# vailhe	2
# vailhes	1
# vais	16
# vaise	7
# vaite	2
# vale	18
# valem	2
# valendo	1
# valente	4
# valentes	1
# valentão	1
# valer	15
# valeria	1
# valerse	1
# vales	5
# valete	2
# valeu	1
# valho	1
# valia	4
# valiam	1
# validado	1
# valor	6
# valoroso	1
# valsa	7
# valsando	1
# valsar	1
# valsas	2
# vamonos	3
# vamos	25
# vantagem	4
# vantagens	1
# vapor	3
# vaporoso	1
# vara	2
# varado	2
# varanda	10
# varandas	6
# varandinha	1
# varandoo	1
# varapau	2
# varar	2
# varias	3
# variedade	1
# variedades	1
# varina	1
# varinas	1
# varinos	1
# varou	1
# varrendo	1
# varrer	3
# varreu	1
# varriam	1
# varriase	1
# varão	5
# varões	2
# vasa	2
# vasando	1
# vaso	8
# vasos	12
# vasta	19
# vastas	3
# vastidão	3
# vasto	17
# vastos	3
# vatil	2
# vaya	1
# vazia	6
# vazias	10
# vazio	3
# vazios	2
# vedes	1
# veemente	1
# veementes	2
# veemência	2
# vegetais	1
# veia	9
# veias	5
# veio	98
# veiolhe	8
# veiolhes	1
# veiome	4
# veja	9
# vejam	2
# vejo	5
# vejome	1
# vejoo	1
# vela	12
# velada	1
# veladas	1
# velado	1
# velador	1
# velar	1
# velas	21
# velavaa	1
# velavase	1
# velha	76
# velhaco	6
# velhas	14
# velhice	14
# velhinho	1
# velho	195
# velhos	25
# veludilho	3
# veludo	57
# veludos	7
# vem	45
# vemos	2
# vemse	1
# vence	1
# vencendo	1
# vencer	2
# vencera	1
# vencia	2
# vencida	3
# vencido	3
# vencidos	2
# venda	4
# vendas	1
# vendavais	2
# vendaval	6
# vende	2
# vender	6
# venderam	1
# venderase	1
# venderlhe	1
# vendia	2
# vendo	44
# vendoa	4
# vendoo	6
# veneno	2
# venerado	1
# venerando	1
# venerar	1
# veneração	9
# venerável	6
# venezianas	1
# venha	13
# venham	2
# venhas	6
# venho	10
# venhome	1
# vens	10
# venta	1
# ventas	1
# vento	27
# ventos	1
# ventre	8
# ventresinho	1
# ventura	2
# venu	2
# ver	188
# veras	1
# verbena	10
# verbo	2
# verbos	2
# verbosidade	1
# verdade	113
# verdadeira	7
# verdadeiramente	8
# verdadeiras	1
# verdadeiro	13
# verdadeiros	3
# verdades	2
# verdadesinhas	1
# verde	44
# verdeclaros	1
# verdeescura	2
# verdeescuro	1
# verdeescuros	1
# verdegarrafa	1
# verdejando	2
# verdejava	3
# verdenegra	1
# verdenegro	2
# verdes	10
# verdura	3
# verduras	5
# vereador	1
# vereda	2
# verei	2
# verem	2
# veremos	2
# vergando	1
# vergastadas	3
# vergastando	1
# vergastar	1
# vergastas	1
# vergava	1
# vergavam	1
# vergavamse	1
# vergonha	21
# vergou	1
# vergões	1
# veria	9
# veriam	1
# verificando	1
# verificar	3
# verificou	4
# verlhe	3
# verlhes	1
# vermelha	18
# vermelhas	6
# vermelhejando	1
# vermelhejava	1
# vermelhejavamlhe	1
# vermelhidão	2
# vermelho	40
# vermelhos	8
# vermelhão	1
# vermina	3
# vermos	1
# vermute	4
# verniz	22
# vernizes	1
# verosimilhança	2
# verosímil	1
# vers	1
# versalhada	3
# verse	2
# verselhe	1
# versinhos	1
# verso	7
# versos	15
# versículos	2
# verte	2
# verticais	1
# vertigem	1
# vertigens	1
# verve	8
# very	1
# verá	1
# verás	2
# verão	45
# verídico	1
# vesgos	1
# veste	1
# vestete	2
# vestia	5
# vestiam	1
# vestiase	2
# vestida	23
# vestidas	2
# vestido	53
# vestidos	19
# vestimenta	1
# vestindo	3
# vestir	11
# vestira	1
# vestiram	1
# vestirnos	1
# vestirse	3
# vestiu	1
# veston	2
# vestuário	1
# vestígio	1
# vestígios	3
# veterano	2
# veux	2
# vexada	2
# vexado	2
# vexame	1
# vez	172
# vezes	133
# vi	13
# via	56
# viaa	5
# viagem	29
# viagens	10
# viajado	1
# viajam	1
# viajando	2
# viajantes	2
# viajar	4
# viajara	3
# viajou	1
# vialhe	1
# viam	4
# viame	1
# viamna	1
# viao	2
# vias	1
# viase	4
# viação	1
# vibrando	2
# vibrante	4
# vibrar	4
# vibrava	1
# vibravam	1
# vibração	4
# vibrou	4
# vicecônsul	1
# vicejante	1
# viciosas	1
# viciosos	1
# vida	151
# vide	1
# vidinha	1
# vidrado	2
# vidraça	8
# vidraças	10
# vidrilhos	2
# vidro	11
# vidros	15
# vie	1
# viela	3
# vielas	2
# viendrait	1
# vienenses	1
# vier	3
# viera	50
# vieram	8
# vieramlhe	1
# viesse	15
# viessem	2
# viesses	1
# vieste	2
# vieux	1
# vigas	1
# vigiar	3
# vigiava	1
# vigilante	1
# vigor	1
# vigorosamente	1
# vigília	2
# vil	6
# vila	11
# vilas	2
# vilipendiar	1
# vilão	3
# vim	8
# vime	1
# vimonos	1
# vimos	4
# vincada	1
# vincos	1
# vinda	5
# vindo	21
# vindolhe	1
# vingado	2
# vingança	6
# vingar	2
# vingarse	1
# vingou	1
# vinha	100
# vinhalhe	1
# vinham	7
# vinhamse	1
# vinhase	2
# vinhaça	1
# vinhedos	1
# vinho	16
# vinhos	9
# vinte	15
# vintista	1
# vinténs	1
# vio	1
# viola	2
# violenta	1
# violentamente	12
# violentas	3
# violento	6
# violeta	3
# violetas	3
# violoncelos	1
# violência	6
# vir	73
# vira	50
# viraa	5
# viraas	1
# viragos	1
# viram	3
# virando	1
# virandoa	1
# virandose	1
# virao	3
# virase	1
# virem	2
# vires	1
# virgem	4
# virgens	1
# virginais	1
# virginal	5
# viria	6
# viril	4
# virilmente	1
# virou	4
# virrsconde	3
# virtude	5
# virtudes	1
# virtuosa	2
# virtuosas	1
# virtuoso	1
# virá	2
# virão	1
# visco	1
# visconde	13
# viscondessa	19
# viscosa	1
# viseira	2
# visinho	2
# visita	29
# visitado	1
# visitalos	1
# visitar	11
# visitarao	3
# visitas	6
# visitasse	1
# visitava	4
# visse	6
# vissem	1
# vista	22
# vistas	3
# viste	7
# visto	30
# vistoria	1
# vistosamente	1
# vistoso	2
# vistosos	1
# visão	4
# visíveis	1
# visível	2
# vite	1
# vitrine	1
# vitrines	1
# vitória	13
# viu	39
# viua	3
# viume	1
# viuos	1
# viuse	1
# viva	22
# vivacidade	2
# vivam	1
# vivamente	20
# vivas	9
# vivazes	1
# vive	17
# vivem	3
# vivemos	4
# vivenda	9
# vivendas	1
# vivendasinha	1
# vivendo	5
# viver	32
# vivera	5
# viveriam	1
# viveríamos	1
# vivesse	1
# viveu	3
# vivi	1
# vivia	26
# viviam	5
# vivido	2
# vivo	28
# vivos	8
# vizinha	5
# vizinhança	7
# vizinho	5
# viçosa	1
# viçosas	1
# viúva	10
# viúvo	9
# voa	1
# voam	2
# voando	2
# voar	4
# voara	1
# voasse	3
# voava	1
# voavam	2
# vocação	2
# vocemecê	2
# vociferar	1
# você	93
# vocês	52
# vogais	1
# voile	1
# voilà	4
# voir	1
# vola	1
# volantes	1
# volo	1
# volta	51
# voltada	2
# voltadas	1
# voltado	6
# voltam	2
# voltamos	1
# voltando	9
# voltandolhe	1
# voltandose	23
# voltar	40
# voltara	16
# voltaram	5
# voltaramse	2
# voltarase	3
# voltarete	3
# voltaretesinho	1
# voltaria	1
# voltariam	1
# voltariana	1
# voltarse	1
# voltas	6
# voltasse	4
# voltassem	1
# voltaste	1
# voltava	22
# voltavam	4
# voltavamlhe	1
# voltavamse	1
# volte	1
# volteando	1
# voltei	2
# volteime	1
# voltes	2
# voltigeuse	1
# volto	3
# voltou	42
# voltouse	32
# voltámos	1
# volume	8
# volumes	2
# voluntariamente	3
# voluntário	1
# voluptuosamente	3
# voluptuosidade	5
# voluptuosidades	2
# voluptuoso	1
# vomitado	1
# vomitar	1
# vomitarlhe	1
# vomito	1
# vontade	21
# voo	3
# voou	1
# voraz	1
# vos	12
# vossa	5
# vosso	1
# vossê	3
# voto	2
# votos	4
# vou	50
# voulezvous	1
# voulhe	1
# voume	5
# vous	11
# voute	1
# vovô	14
# voz	137
# vozeirão	6
# vozes	12
# vozinha	1
# vrai	1
# vulgares	1
# vulto	3
# vá	22
# válidos	1
# várzea	1
# várzeas	1
# vás	6
# váse	2
# vã	4
# vão	24
# vãos	3
# véspera	58
# vésperas	5
# véu	27
# véus	6
# vê	18
# vêem	14
# vêemse	1
# vêla	12
# vêlas	1
# vêlo	4
# vêlos	1
# vêm	2
# vês	4
# víamonos	1
# vício	5
# vícios	2
# vínhamos	1
# vírus	1
# vísceras	2
# vítima	2
# vítimas	1
# vôos	1
# vôtre	1
# wagon	5
# wagons	2
# wagonsalão	3
# waterproof	5
# whist	14
# xadresinho	2
# xadrez	5
# xadrezinho	1
# xairel	1
# xarope	1
# xv	3
# xícara	1
# yes	7
# you	2
# zangado	4
# zangar	3
# zangarse	1
# zangase	1
# zangava	1
# zangouse	2
# zangues	2
# zelava	1
# zelo	1
# zelosamente	1
# zeloso	1
# zinco	3
# zombarias	1
# zumbir	1
# zumzum	1
# zurzira	1
# zás	7
# Àquela	1
# Á	32
# África	10
# Águeda	1
# Ámen	1
# Ás	16
# Ásia	2
# Átomo	12
# Áustria	7
# Ça	2
# É	354
# Éclogas	1
# Éliseés	1
# És	5
# Êtesvous	1
# Ó	26
# Ópera	1
# Óptimo	1
# à	891
# àquela	26
# àquelas	1
# àquele	18
# àqueles	1
# às	2
# á	5
# ácida	1
# ádito	1
# ágeis	1
# água	71
# águar	1
# águaráz	1
# águas	20
# águias	1
# álbum	1
# álbuns	2
# álcoois	1
# álcool	2
# áleas	1
# árabe	5
# árabes	2
# ária	2
# árias	1
# árvore	6
# árvores	58
# ás	221
# áspera	4
# ásperas	2
# áspero	5
# ásperos	1
# átomo	6
# átomos	2
# ângulo	2
# ânsia	1
# ãããããah	2
# ça	2
# é	942
# ébanos	1
# écloga	2
# écrire	1
# égua	10
# éguas	5
# éguasita	2
# éo	3
# épinards	1
# época	1
# és	25
# ése	1
# éter	1
# été	2
# ênfase	1
# êtes	2
# êxtase	10
# êxtaseouse	1
# êxtases	1
# ía	33
# íamos	3
# íase	4
# ídolo	3
# ímpeto	4
# ímpia	2
# índia	19
# índios	1
# íntimo	37
# íntimos	9
# ó	10
# óculo	2
# óculos	5
# ódio	18
# ódios	1
# ódiosinho	1
# óleo	4
# ónibus	5
# ópera	3
# óperacómica	1
# óptimo	5
# órbita	1
# órgão	2
# últimos	16
# única	29
# único	22
# únicos	1
# úteis	4
# útero	1
# útil	7

# %% [markdown]
# ## Sorting
# The results are not sorted. Let's sort them by frequency (the words with higher occurrence first).

# %% [markdown]
# ### Mapper
# Complete with the code for the mapper.

# %%
# %%file mapper_sort.py
#!/usr/bin/env python

# import sys
import sys
# import string library function  
import string  

# input comes from STDIN (standard input)
for line in sys.stdin:
    # remove leading and trailing whitespace
    line = line.strip()
    # remove punctuation characters
    line = line.translate(str.maketrans('', '', string.punctuation+'«»'))
    # split the line into words
    word, count = line.split('\t')
    
    count = int(count)
    
    print('%05d\t%s' % (count, word))
# Out:
# Overwriting mapper_sort.py

# %% [markdown]
# ### Reducer

# %%
# %%file reducer_sort.py
#!/usr/bin/python

import sys
import string

# input comes from STDIN
for line in sys.stdin:
    # remove leading and trailing whitespace
    line = line.strip()

    # parse the input we got from mapper.py
    count, word = line.split('\t')

    # convert count (currently a string) to int
    count = int(count)
    
    print('%d\t%s' % (count, word))
# Out:
# Overwriting reducer_sort.py

# %% [markdown]
# ### Hadoop standalone mode execution

# %% [markdown]
# The output directory needs to be cleared...

# %%
rm -rf results_sort

# %% [markdown]
# #### Submitting the job
#
# The _hadoop_ command is used to submit the mapreduce job to the cluster...

# %%
# !hadoop jar /opt/hadoop-3.2.0/share/hadoop/tools/lib/hadoop-*streaming*.jar -files mapper_sort.py,reducer_sort.py -mapper mapper_sort.py -reducer reducer_sort.py -input results_words/part-* -output results_sort
# Out:
# 2020-10-02 18:53:25,380 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2020-10-02 18:53:25,472 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2020-10-02 18:53:25,472 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2020-10-02 18:53:25,491 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2020-10-02 18:53:25,753 INFO mapred.FileInputFormat: Total input files to process : 1
# 2020-10-02 18:53:25,779 INFO mapreduce.JobSubmitter: number of splits:1
# 2020-10-02 18:53:26,009 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local735000171_0001
# 2020-10-02 18:53:26,010 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2020-10-02 18:53:26,310 INFO mapred.LocalDistributedCacheManager: Localized file:/home/jovyan/work/mapper_sort.py as file:/tmp/hadoop-jovyan/mapred/local/job_local735000171_0001_aec9e115-2711-440e-81c8-0db5bd2f3283/mapper_sort.py
# 2020-10-02 18:53:26,339 INFO mapred.LocalDistributedCacheManager: Localized file:/home/jovyan/work/reducer_sort.py as file:/tmp/hadoop-jovyan/mapred/local/job_local735000171_0001_3e0e6eee-a892-4e4d-8782-fe949c421e6b/reducer_sort.py
# 2020-10-02 18:53:26,458 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2020-10-02 18:53:26,459 INFO mapreduce.Job: Running job: job_local735000171_0001
# 2020-10-02 18:53:26,466 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2020-10-02 18:53:26,469 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2020-10-02 18:53:26,476 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2020-10-02 18:53:26,477 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-10-02 18:53:26,520 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2020-10-02 18:53:26,535 INFO mapred.LocalJobRunner: Starting task: attempt_local735000171_0001_m_000000_0
# 2020-10-02 18:53:26,583 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2020-10-02 18:53:26,583 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-10-02 18:53:26,617 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2020-10-02 18:53:26,626 INFO mapred.MapTask: Processing split: file:/home/jovyan/work/results_words/part-00000:0+252357
# 2020-10-02 18:53:26,644 INFO mapred.MapTask: numReduceTasks: 1
# 2020-10-02 18:53:26,724 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2020-10-02 18:53:26,724 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2020-10-02 18:53:26,724 INFO mapred.MapTask: soft limit at 83886080
# 2020-10-02 18:53:26,724 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2020-10-02 18:53:26,724 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2020-10-02 18:53:26,727 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2020-10-02 18:53:26,732 INFO streaming.PipeMapRed: PipeMapRed exec [/home/jovyan/work/./mapper_sort.py]
# 2020-10-02 18:53:26,737 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2020-10-02 18:53:26,737 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2020-10-02 18:53:26,738 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2020-10-02 18:53:26,738 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2020-10-02 18:53:26,739 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2020-10-02 18:53:26,739 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2020-10-02 18:53:26,739 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2020-10-02 18:53:26,740 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2020-10-02 18:53:26,740 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2020-10-02 18:53:26,741 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2020-10-02 18:53:26,741 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2020-10-02 18:53:26,741 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2020-10-02 18:53:26,786 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:53:26,786 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:53:26,788 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:53:26,809 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:53:26,843 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:53:26,854 INFO streaming.PipeMapRed: Records R/W=11665/1
# 2020-10-02 18:53:27,081 INFO streaming.PipeMapRed: MRErrorThread done
# 2020-10-02 18:53:27,082 INFO streaming.PipeMapRed: mapRedFinished
# 2020-10-02 18:53:27,087 INFO mapred.LocalJobRunner:
# 2020-10-02 18:53:27,087 INFO mapred.MapTask: Starting flush of map output
# 2020-10-02 18:53:27,088 INFO mapred.MapTask: Spilling map output
# 2020-10-02 18:53:27,088 INFO mapred.MapTask: bufstart = 0; bufend = 340425; bufvoid = 104857600
# 2020-10-02 18:53:27,088 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26123708(104494832); length = 90689/6553600
# 2020-10-02 18:53:27,192 INFO mapred.MapTask: Finished spill 0
# 2020-10-02 18:53:27,208 INFO mapred.Task: Task:attempt_local735000171_0001_m_000000_0 is done. And is in the process of committing
# 2020-10-02 18:53:27,211 INFO mapred.LocalJobRunner: Records R/W=11665/1
# 2020-10-02 18:53:27,211 INFO mapred.Task: Task 'attempt_local735000171_0001_m_000000_0' done.
# 2020-10-02 18:53:27,222 INFO mapred.Task: Final Counters for attempt_local735000171_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=431920
# 		FILE: Number of bytes written=1081834
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=22673
# 		Map output records=22673
# 		Map output bytes=340425
# 		Map output materialized bytes=385777
# 		Input split bytes=99
# 		Combine input records=0
# 		Spilled Records=22673
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=204472320
# 	File Input Format Counters
# 		Bytes Read=254341
# 2020-10-02 18:53:27,222 INFO mapred.LocalJobRunner: Finishing task: attempt_local735000171_0001_m_000000_0
# 2020-10-02 18:53:27,222 INFO mapred.LocalJobRunner: map task executor complete.
# 2020-10-02 18:53:27,226 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2020-10-02 18:53:27,227 INFO mapred.LocalJobRunner: Starting task: attempt_local735000171_0001_r_000000_0
# 2020-10-02 18:53:27,246 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2020-10-02 18:53:27,246 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2020-10-02 18:53:27,246 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2020-10-02 18:53:27,250 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@781689a3
# 2020-10-02 18:53:27,253 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2020-10-02 18:53:27,279 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=325163424, maxSingleShuffleLimit=81290856, mergeThreshold=214607872, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2020-10-02 18:53:27,293 INFO reduce.EventFetcher: attempt_local735000171_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2020-10-02 18:53:27,347 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local735000171_0001_m_000000_0 decomp: 385773 len: 385777 to MEMORY
# 2020-10-02 18:53:27,362 INFO reduce.InMemoryMapOutput: Read 385773 bytes from map-output for attempt_local735000171_0001_m_000000_0
# 2020-10-02 18:53:27,364 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 385773, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->385773
# 2020-10-02 18:53:27,367 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2020-10-02 18:53:27,369 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2020-10-02 18:53:27,372 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2020-10-02 18:53:27,383 INFO mapred.Merger: Merging 1 sorted segments
# 2020-10-02 18:53:27,384 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 385765 bytes
# 2020-10-02 18:53:27,423 INFO reduce.MergeManagerImpl: Merged 1 segments, 385773 bytes to disk to satisfy reduce memory limit
# 2020-10-02 18:53:27,424 INFO reduce.MergeManagerImpl: Merging 1 files, 385777 bytes from disk
# 2020-10-02 18:53:27,425 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2020-10-02 18:53:27,425 INFO mapred.Merger: Merging 1 sorted segments
# 2020-10-02 18:53:27,427 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 385765 bytes
# 2020-10-02 18:53:27,428 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2020-10-02 18:53:27,436 INFO streaming.PipeMapRed: PipeMapRed exec [/home/jovyan/work/./reducer_sort.py]
# 2020-10-02 18:53:27,448 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2020-10-02 18:53:27,453 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2020-10-02 18:53:27,464 INFO mapreduce.Job: Job job_local735000171_0001 running in uber mode : false
# 2020-10-02 18:53:27,465 INFO mapreduce.Job:  map 100% reduce 0%
# 2020-10-02 18:53:27,489 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:53:27,490 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:53:27,492 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:53:27,508 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:53:27,537 INFO streaming.PipeMapRed: Records R/W=8453/1
# 2020-10-02 18:53:27,547 INFO streaming.PipeMapRed: R/W/S=10000/366/0 in:NA [rec/s] out:NA [rec/s]
# 2020-10-02 18:53:27,673 INFO streaming.PipeMapRed: MRErrorThread done
# 2020-10-02 18:53:27,679 INFO streaming.PipeMapRed: mapRedFinished
# 2020-10-02 18:53:27,680 INFO mapred.Task: Task:attempt_local735000171_0001_r_000000_0 is done. And is in the process of committing
# 2020-10-02 18:53:27,681 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2020-10-02 18:53:27,681 INFO mapred.Task: Task attempt_local735000171_0001_r_000000_0 is allowed to commit now
# 2020-10-02 18:53:27,682 INFO output.FileOutputCommitter: Saved output of task 'attempt_local735000171_0001_r_000000_0' to file:/home/jovyan/work/results_sort
# 2020-10-02 18:53:27,683 INFO mapred.LocalJobRunner: Records R/W=8453/1 > reduce
# 2020-10-02 18:53:27,684 INFO mapred.Task: Task 'attempt_local735000171_0001_r_000000_0' done.
# 2020-10-02 18:53:27,686 INFO mapred.Task: Final Counters for attempt_local735000171_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=1203506
# 		FILE: Number of bytes written=1721948
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=272
# 		Reduce shuffle bytes=385777
# 		Reduce input records=22673
# 		Reduce output records=22673
# 		Spilled Records=22673
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=9
# 		Total committed heap usage (bytes)=204996608
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=254337
# 2020-10-02 18:53:27,689 INFO mapred.LocalJobRunner: Finishing task: attempt_local735000171_0001_r_000000_0
# 2020-10-02 18:53:27,690 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2020-10-02 18:53:28,466 INFO mapreduce.Job:  map 100% reduce 100%
# 2020-10-02 18:53:28,467 INFO mapreduce.Job: Job job_local735000171_0001 completed successfully
# 2020-10-02 18:53:28,500 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=1635426
# 		FILE: Number of bytes written=2803782
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=22673
# 		Map output records=22673
# 		Map output bytes=340425
# 		Map output materialized bytes=385777
# 		Input split bytes=99
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=272
# 		Reduce shuffle bytes=385777
# 		Reduce input records=22673
# 		Reduce output records=22673
# 		Spilled Records=45346
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=9
# 		Total committed heap usage (bytes)=409468928
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=254341
# 	File Output Format Counters
# 		Bytes Written=254337
# 2020-10-02 18:53:28,500 INFO streaming.StreamJob: Output directory: results_sort

# %% [markdown]
# #### Checking the results
# The result is stored in directory results.

# %%
# !cat results_sort/part-*
# Out:
# 1	esmagadas
# 1	esguios
# 1	consultarme
# 1	esguias
# 1	consultas
# 1	esgueirouse
# 1	esgueiravase
# 1	esguedelhados
# 1	consultavame
# 1	esguedelhadas
# 1	surdir
# 1	esgrouviada
# 1	consumado
# 1	esgotouo
# 1	esgoto
# 1	esgotara
# 1	esgotada
# 1	esgaçava
# 1	esgazearemse
# 1	consumar
# 1	esgatanhando
# 1	consumação
# 1	esganiçava
# 1	esganiçados
# 1	esganiçado
# 1	esganiçada
# 1	esganalo
# 1	esgalgado
# 1	esgalgada
# 1	surdia
# 1	esfuzia
# 1	esfuracou
# 1	esfuracando
# 1	esfuminho
# 1	esfumadas
# 1	esfumada
# 1	esfriar
# 1	consumidas
# 1	consumindo
# 1	esfregar
# 1	consumiria
# 1	esfrangalhalo
# 1	surdas
# 1	contacto
# 1	esforçara
# 1	esforçandose
# 1	esforçado
# 1	esfomeados
# 1	esfomeado
# 1	esfolou
# 1	esfolhavase
# 1	esfolhavamse
# 1	esfolhadas
# 1	esfolado
# 1	esfiava
# 1	contactos
# 1	esfarrapada
# 1	esfaqueandose
# 1	esfalfados
# 1	contada
# 1	esfalfada
# 1	esfaimado
# 1	esfacelamento
# 1	contagiosa
# 1	escárnios
# 1	escute
# 1	contaminado
# 1	Esvaziou
# 1	contandolha
# 1	escutassem
# 1	escutarem
# 1	contandolhe
# 1	contaram
# 1	escutandolhe
# 1	contaremlhe
# 1	Apalpavalhe
# 1	contaria
# 1	escusam
# 1	escusa
# 1	contarlhe
# 1	contarte
# 1	contasse
# 1	escurecida
# 1	Apalpouo
# 1	vissem
# 1	Eternidade
# 1	suprir
# 1	suprimir
# 1	contavao
# 1	escudo
# 1	contavaslhe
# 1	conte
# 1	contemplala
# 1	contemplandoo
# 1	escrupulosamente
# 1	suprimido
# 1	contemplaraa
# 1	contemplativa
# 1	escriturada
# 1	escritos
# 1	escritores
# 1	suprimida
# 1	contemplavao
# 1	escritas
# 1	contemploua
# 1	escrevêlo
# 1	escrevo
# 1	escrevinho
# 1	escrevinhando
# 1	escrevinhador
# 1	escreviam
# 1	suprimi
# 1	contemplouse
# 1	contemporânea
# 1	escreveume
# 1	contemporâneas
# 1	contenos
# 1	escreves
# 1	contentamento
# 1	contentamos
# 1	contentamse
# 1	contentandose
# 1	Eufrates
# 1	contentara
# 1	escravos
# 1	contentaria
# 1	supremamente
# 1	Eurico
# 1	escovarse
# 1	escovar
# 1	contento
# 1	escoucinhe
# 1	supracómico
# 1	escorridos
# 1	contentíssimo
# 1	Apanhar
# 1	escorregoulhe
# 1	contesse
# 1	escorregava
# 1	escorregarlhe
# 1	Aparece
# 1	suporta
# 1	contevese
# 1	escorraçouo
# 1	conteúdo
# 1	escoria
# 1	Evangelistas
# 1	escopeta
# 1	escoouse
# 1	contida
# 1	continham
# 1	visitasse
# 1	escondidamente
# 1	continhos
# 1	escondiam
# 1	continuam
# 1	Aparecia
# 1	supondo
# 1	esconderalhe
# 1	continuamente
# 1	continuara
# 1	esconde
# 1	escoltavam
# 1	escolhidos
# 1	escolhido
# 1	escolhidas
# 1	continuaria
# 1	continuassem
# 1	continuação
# 1	suplício
# 1	escolhe
# 1	escolas
# 1	escolares
# 1	contornos
# 1	contradança
# 1	contradanças
# 1	escoavase
# 1	suplicou
# 1	escoava
# 1	Apertaram
# 1	escoar
# 1	esclarecêlo
# 1	esclareceu
# 1	esclarecessem
# 1	suplicava
# 1	contrafeitos
# 1	escavacar
# 1	Evolução
# 1	escavacado
# 1	escavacadas
# 1	escasso
# 1	escasseava
# 1	escassa
# 1	escarvava
# 1	escarros
# 1	contraponto
# 1	escarravalhe
# 1	escarrarlhe
# 1	escarraria
# 1	escarolados
# 1	escarnica
# 1	escarnecia
# 1	contraria
# 1	contrariado
# 1	escarcela
# 1	escapouselhe
# 1	escapouse
# 1	escapou
# 1	escapavamlhe
# 1	escapava
# 1	escapassem
# 1	escapasse
# 1	suplicantes
# 1	escaparalhe
# 1	contrariar
# 1	escapado
# 1	escapa
# 1	escanifrado
# 1	escangalhasse
# 1	escangalhando
# 1	escandinávia
# 1	escandalosa
# 1	Exa
# 1	contrariava
# 1	escandalizava
# 1	escandalizar
# 1	suplicando
# 1	escancarado
# 1	escaldava
# 1	escaldar
# 1	escalavrados
# 1	escalavrada
# 1	escalas
# 1	contrariedades
# 1	contrariou
# 1	contrastando
# 1	Examinava
# 1	contraste
# 1	escachar
# 1	escabrosos
# 1	escabroso
# 1	escabelo
# 1	esbugalhados
# 1	esbugalhado
# 1	esbrazeavamselhe
# 1	esbrazeada
# 1	esbraseara
# 1	contratempo
# 1	esboçara
# 1	esboçar
# 1	esboçado
# 1	esborratado
# 1	esborrachavao
# 1	esborrachavalhe
# 1	supersticioso
# 1	esborrachasse
# 1	esborracham
# 1	Apertaramse
# 1	esbofetear
# 1	esbelto
# 1	esbelta
# 1	esbatidos
# 1	esbatido
# 1	esbatida
# 1	contribuir
# 1	esbarrondado
# 1	esbarrar
# 1	esbanjar
# 1	esbaforidos
# 1	contricto
# 1	esbaforidamente
# 1	Exas
# 1	Exaª
# 1	contristada
# 1	Excªs
# 1	errou
# 1	controvérsias
# 1	contrários
# 1	Exercitome
# 1	erravam
# 1	contém
# 1	errariam
# 1	errara
# 1	errar
# 1	contínua
# 1	errante
# 1	errados
# 1	errado
# 1	erra
# 1	superficial
# 1	ermida
# 1	erguime
# 1	erguidos
# 1	contínuo
# 1	contínuos
# 1	convalescente
# 1	superficiais
# 1	erguiam
# 1	erguiaa
# 1	convalescia
# 1	convemlhe
# 1	ergueuo
# 1	Existia
# 1	convencera
# 1	erguese
# 1	visitalos
# 1	convencidos
# 1	convencional
# 1	convenientemente
# 1	conventos
# 1	convençam
# 1	convenção
# 1	conversarem
# 1	erguelo
# 1	ergo
# 1	eremita
# 1	conversaremos
# 1	conversarmos
# 1	eralhe
# 1	conversação
# 1	equívocos
# 1	visitado
# 1	equivoca
# 1	equilibravase
# 1	equilibrarem
# 1	sumo
# 1	equestre
# 1	sumiço
# 1	epopeia
# 1	conversações
# 1	conversou
# 1	sumiuse
# 1	epigrama
# 1	epiderme
# 1	epidemias
# 1	conversão
# 1	epatant
# 1	Apertava
# 1	enxugou
# 1	enxugar
# 1	sumirase
# 1	enxovalhalo
# 1	enxovalhados
# 1	converterao
# 1	convertido
# 1	enxovalhada
# 1	enxotar
# 1	enxergão
# 1	sumiramse
# 1	envolvêlo
# 1	convida
# 1	envolvidas
# 1	envolviaos
# 1	envolviao
# 1	convidao
# 1	envolveulhe
# 1	envolveuas
# 1	sumiram
# 1	convidarao
# 1	envolvendoos
# 1	sumindo
# 1	envolvelo
# 1	envoltos
# 1	convidasse
# 1	convidativas
# 1	enviei
# 1	envidraçado
# 1	Exmo
# 1	convidativo
# 1	enviados
# 1	Explicação
# 1	convidei
# 1	envernizado
# 1	envergonhouse
# 1	envergonhou
# 1	envergonho
# 1	envergonhavam
# 1	envergonhava
# 1	envergando
# 1	envenenar
# 1	convidoume
# 1	envelhecido
# 1	convidouo
# 1	envelheciam
# 1	envelhecendo
# 1	ébanos
# 1	enumerar
# 1	conviesse
# 1	entusiastas
# 1	convivência
# 1	sumiaselhe
# 1	convés
# 1	entusiasmava
# 1	entusiasmara
# 1	entusiasmar
# 1	copada
# 1	entulhado
# 1	entufada
# 1	entrudo
# 1	copiado
# 1	entronisado
# 1	entristecida
# 1	entristeciao
# 1	entristeciam
# 1	entristecia
# 1	sumiase
# 1	entristecelo
# 1	entristece
# 1	entreviu
# 1	entrevistos
# 1	entrevisto
# 1	entrevista
# 1	copiando
# 1	sumariamente
# 1	copiosamente
# 1	entrevendo
# 1	entretivesse
# 1	entretinhao
# 1	sumaria
# 1	sumamente
# 1	entreterem
# 1	entretemse
# 1	entretanto
# 1	entremetidos
# 1	entremeados
# 1	Abalemos
# 1	entrelaçavam
# 1	Explicoulhe
# 1	copiosas
# 1	entregues
# 1	entregue
# 1	entregoume
# 1	Explicoulho
# 1	sulcavam
# 1	entregava
# 1	sulcarao
# 1	viscosa
# 1	entregaralhe
# 1	entregaralhas
# 1	entregara
# 1	copioso
# 1	entregao
# 1	entregandolhe
# 1	entregando
# 1	sujou
# 1	entrechocar
# 1	entreacto
# 1	copiosos
# 1	entreabrindo
# 1	entreabria
# 1	entreabertos
# 1	copiou
# 1	copista
# 1	copita
# 1	coradinhas
# 1	entravalhe
# 1	cordeiros
# 1	entrasse
# 1	entrase
# 1	sujos
# 1	cordéis
# 1	entrarem
# 1	cordões
# 1	entraralhe
# 1	coreto
# 1	cornetada
# 1	entrapada
# 1	cornetear
# 1	cornijas
# 1	Eça
# 1	entradas
# 1	cornos
# 1	FLOR
# 1	FORTE
# 1	entorpecido
# 1	entorne
# 1	entoou
# 1	entontecido
# 1	entontecia
# 1	entontecera
# 1	entoação
# 1	entoam
# 1	sujasteme
# 1	coroando
# 1	enterroo
# 1	coroas
# 1	enterravase
# 1	enterrava
# 1	enterrarase
# 1	Fabio
# 1	coroassem
# 1	enterrandose
# 1	Apertou
# 1	enterralo
# 1	enterrados
# 1	coronha
# 1	coronhadas
# 1	coronhas
# 1	enterra
# 1	corpanzil
# 1	enternecidos
# 1	corra
# 1	enternecidas
# 1	enternecidamente
# 1	corre
# 1	enterneciase
# 1	Fachadas
# 1	enterneceu
# 1	enternecera
# 1	enternecedora
# 1	enternece
# 1	Falara
# 1	correcional
# 1	correctos
# 1	entendi
# 1	entendessem
# 1	entendesse
# 1	entendes
# 1	corredia
# 1	entendedores
# 1	entendedor
# 1	correia
# 1	entendam
# 1	correias
# 1	correligionário
# 1	entalhaduras
# 1	entalhado
# 1	entalhadas
# 1	entalava
# 1	entalara
# 1	entalandoo
# 1	correlo
# 1	entalados
# 1	correm
# 1	Falaste
# 1	entaladas
# 1	entalada
# 1	entabulados
# 1	ensurdecidas
# 1	ensopava
# 1	ensoparia
# 1	ensopadas
# 1	ensinoulhe
# 1	ensinou
# 1	correrias
# 1	suicídio
# 1	ensinavalhe
# 1	Fale
# 1	sugeriraa
# 1	ensinarei
# 1	correspondia
# 1	correspondiase
# 1	ensinando
# 1	ensinados
# 1	corresse
# 1	ensanguentadas
# 1	ensaios
# 1	ensaiando
# 1	ensaboar
# 1	enrugada
# 1	sugeridos
# 1	enroupando
# 1	enroscar
# 1	sugerido
# 1	sugeria
# 1	enrolou
# 1	enrolavaselhe
# 1	sugandoa
# 1	sufocouo
# 1	correto
# 1	corriamse
# 1	corrigiu
# 1	enrodilharnos
# 1	enrodilhando
# 1	enredos
# 1	enredarse
# 1	enredar
# 1	enramelhetados
# 1	enramalhetados
# 1	sufocavam
# 1	corrimão
# 1	enovelado
# 1	enormidade
# 1	corrompidos
# 1	corroo
# 1	enojava
# 1	corta
# 1	Falem
# 1	enodoa
# 1	enlouquecera
# 1	cortados
# 1	sufocassem
# 1	cortando
# 1	enlevadas
# 1	sufocaram
# 1	cortara
# 1	cortarem
# 1	enleava
# 1	enleara
# 1	enleado
# 1	enlaçoua
# 1	enlaçavam
# 1	enlaçava
# 1	enlaçaramno
# 1	enlaçar
# 1	enlaçados
# 1	sufocara
# 1	enlatado
# 1	enlameados
# 1	enlameado
# 1	enjoaram
# 1	enguiço
# 1	cortejo
# 1	engraçadas
# 1	Falhámos
# 1	engraxadas
# 1	engravatado
# 1	engrandecer
# 1	engordar
# 1	engordado
# 1	engonços
# 1	engomado
# 1	sufocante
# 1	engoliu
# 1	sufocandose
# 1	engolindo
# 1	engolidos
# 1	engodo
# 1	sufocando
# 1	engelhadas
# 1	engastada
# 1	Faloulhe
# 1	enganos
# 1	Faloume
# 1	enganado
# 1	sufocadas
# 1	engalfinhandose
# 1	engalfinhados
# 1	engalfinhado
# 1	enfureciam
# 1	enfureceu
# 1	enfurecerte
# 1	enfunavamse
# 1	enfunadas
# 1	enfronhara
# 1	Falouse
# 1	enfrascome
# 1	enfraquecia
# 1	enforcarase
# 1	enforcar
# 1	enforcados
# 1	enfiouas
# 1	cortejou
# 1	suficientemente
# 1	cortesão
# 1	enfiavam
# 1	enfiava
# 1	enfiarem
# 1	enfiara
# 1	Apetecete
# 1	cortez
# 1	cortina
# 1	sueco
# 1	enfezado
# 1	sudários
# 1	enferrujada
# 1	sudário
# 1	enfermeira
# 1	enferma
# 1	Faltalhe
# 1	enfeitado
# 1	enfastiavam
# 1	enfastiavaa
# 1	cortoulhe
# 1	enfarruscada
# 1	enfardelarme
# 1	enfardelar
# 1	enfant
# 1	enfado
# 1	enevoavamselhe
# 1	enevoavam
# 1	enevoava
# 1	enevoaramse
# 1	sucumbiu
# 1	sucumbir
# 1	enevoada
# 1	enervavam
# 1	corujas
# 1	energia
# 1	enegreceu
# 1	enegrecendo
# 1	endireitou
# 1	endereço
# 1	encurtar
# 1	encruzilhada
# 1	encruzadas
# 1	encrespado
# 1	encovados
# 1	encovado
# 1	encouraçado
# 1	encostas
# 1	corzinha
# 1	encostar
# 1	cosa
# 1	coscuvilhice
# 1	encostadas
# 1	cosiamlhe
# 1	encore
# 1	sucumbindo
# 1	encontrão
# 1	encontrálo
# 1	encontrrárra
# 1	encontrouse
# 1	sucumbidos
# 1	encontroua
# 1	cosido
# 1	costela
# 1	encontreios
# 1	encontrei
# 1	encontravao
# 1	costelas
# 1	encontravaa
# 1	costuma
# 1	encontraste
# 1	Faltate
# 1	Família
# 1	encontrase
# 1	encontrará
# 1	encontrarte
# 1	encontrarseiam
# 1	encontrarsehia
# 1	encontrarse
# 1	encontrares
# 1	encontraremse
# 1	encontraremos
# 1	encontraramse
# 1	costumada
# 1	encontraraa
# 1	costumadas
# 1	costumas
# 1	encontrandose
# 1	costumier
# 1	encontramse
# 1	encontram
# 1	costumo
# 1	costumé
# 1	costuras
# 1	costureira
# 1	encomendei
# 1	sucumbiam
# 1	encomendado
# 1	costureiras
# 1	encolhidas
# 1	cotilon
# 1	encolhiase
# 1	coubera
# 1	encolheuse
# 1	couches
# 1	encolhera
# 1	couché
# 1	coudelarias
# 1	encoberta
# 1	enclausurada
# 1	enchurros
# 1	enchumaçou
# 1	enchumaçaramlho
# 1	enchiase
# 1	enchiamselhe
# 1	sucessos
# 1	couraçados
# 1	enchialhe
# 1	couves
# 1	couvrepieds
# 1	visco
# 1	encheramse
# 1	cova
# 1	enchente
# 1	Fanqueiros
# 1	covardemente
# 1	enchelo
# 1	encharcara
# 1	virão
# 1	encharcada
# 1	encerrada
# 1	encerra
# 1	encerados
# 1	encerado
# 1	órbita
# 1	encavacou
# 1	covas
# 1	encatarroados
# 1	encatarroado
# 1	encarregou
# 1	encarrego
# 1	encarregassem
# 1	encarregaria
# 1	encarregara
# 1	covilhete
# 1	sucedia
# 1	encarniçados
# 1	virtuoso
# 1	encarnava
# 1	encarnado
# 1	encarnadas
# 1	Faraónica
# 1	encardida
# 1	covis
# 1	sucedera
# 1	encarapinhado
# 1	encarado
# 1	Fazemos
# 1	encantoua
# 1	cozer
# 1	cozidos
# 1	encantavao
# 1	sucedendo
# 1	cozinhado
# 1	encantaria
# 1	encantaramno
# 1	encantara
# 1	encantame
# 1	coçala
# 1	crachá
# 1	crassa
# 1	crassas
# 1	encanchado
# 1	encalmado
# 1	encalhara
# 1	encalhada
# 1	encalacrar
# 1	encalacrado
# 1	encaixilhando
# 1	sucedem
# 1	encafuar
# 1	encafuado
# 1	cravada
# 1	encadernação
# 1	encadernarme
# 1	encadeava
# 1	en
# 1	emudecido
# 1	emudecia
# 1	Fazer
# 1	emudeceua
# 1	cravadas
# 1	emudeceram
# 1	suceda
# 1	empurrouo
# 1	empurroua
# 1	cravado
# 1	empurravao
# 1	subúrbios
# 1	empurrandoos
# 1	empurrandolhe
# 1	empurrando
# 1	virtuosas
# 1	empunhando
# 1	Fazesme
# 1	cravandoo
# 1	emprestoulhe
# 1	empresteilhes
# 1	cravarse
# 1	cravava
# 1	emprestamos
# 1	emprestados
# 1	empresa
# 1	empregos
# 1	empregarem
# 1	empregados
# 1	craveiro
# 1	empreender
# 1	Faziao
# 1	emporcalhado
# 1	empolgava
# 1	subtilezas
# 1	empolgando
# 1	empolgada
# 1	empoleirarse
# 1	empoeirado
# 1	empoados
# 1	empoado
# 1	empoadas
# 1	empoada
# 1	emplumados
# 1	emplumado
# 1	emplumada
# 1	emplastros
# 1	emplastro
# 1	empiteirava
# 1	empiteirarse
# 1	empinado
# 1	empilhavamse
# 1	empigem
# 1	empestavam
# 1	empestava
# 1	empertigandose
# 1	empertigadote
# 1	empertigados
# 1	empertigado
# 1	Fazlhe
# 1	emperrara
# 1	craveiros
# 1	empenhara
# 1	cravejada
# 1	empenhando
# 1	empedernidos
# 1	empavoada
# 1	emparvecido
# 1	emparvecida
# 1	empanturrada
# 1	empanando
# 1	empalmado
# 1	empalideciaa
# 1	empalidecia
# 1	cravoulhe
# 1	empalidecer
# 1	empalidecendo
# 1	empalhado
# 1	empalhada
# 1	subterrâneo
# 1	creaturinha
# 1	emolduravam
# 1	1848
# 1	emergiu
# 1	emergir
# 1	substituísse
# 1	emendou
# 1	emendasse
# 1	emendada
# 1	embête
# 1	embuçado
# 1	embutidos
# 1	embusteira
# 1	substituído
# 1	emburguesada
# 1	embuchou
# 1	embuchada
# 1	embrutecidos
# 1	embrutecido
# 1	embrulhouse
# 1	virtudes
# 1	substituila
# 1	credores
# 1	embrulharse
# 1	embrulhara
# 1	embrulhando
# 1	embrulhados
# 1	credulidade
# 1	crença
# 1	crepes
# 1	crepitando
# 1	embriagado
# 1	embranquecera
# 1	embranquecendo
# 1	embotado
# 1	emborrachavam
# 1	emborcados
# 1	crepitante
# 1	embolsando
# 1	substituese
# 1	embirra
# 1	embezerrado
# 1	subsidio
# 1	embelezavam
# 1	subscrição
# 1	embebidas
# 1	embebida
# 1	embebiam
# 1	embebendose
# 1	embebendo
# 1	embebedavase
# 1	embebedavamse
# 1	embebedarse
# 1	embebedado
# 1	embaíra
# 1	crer
# 1	embatucar
# 1	embatucados
# 1	embatucado
# 1	embateu
# 1	embatendo
# 1	embasbacou
# 1	embasbacar
# 1	embasbacados
# 1	embasbacado
# 1	submissão
# 1	embarque
# 1	embarcar
# 1	crescentes
# 1	crescera
# 1	embaraçava
# 1	embaraçar
# 1	embaraçados
# 1	embaraçadora
# 1	cresceu
# 1	embaraçadamente
# 1	embalava
# 1	embalara
# 1	embalala
# 1	Apilharamse
# 1	embaixadores
# 1	cresciam
# 1	embaixada
# 1	embainharei
# 1	embaciavam
# 1	embaciaramlhe
# 1	embaciados
# 1	embaciado
# 1	embaciada
# 1	emassando
# 1	emaranha
# 1	emancipasse
# 1	emanação
# 1	emanava
# 1	emalar
# 1	crescidinho
# 1	submissa
# 1	eléctrica
# 1	crescidos
# 1	eloquentíssimo
# 1	cresmatica
# 1	sublinhara
# 1	Apito
# 1	elogiaram
# 1	elo
# 1	elite
# 1	Apoiado
# 1	elevouse
# 1	elevou
# 1	crespamente
# 1	elevasse
# 1	elevarse
# 1	elevaria
# 1	elevarase
# 1	virilmente
# 1	elevado
# 1	elevadas
# 1	Fedro
# 1	Apolos
# 1	crestada
# 1	crestados
# 1	creste
# 1	Feira
# 1	Feito
# 1	eleitoral
# 1	eleita
# 1	elegâncias
# 1	cresçam
# 1	cretinisados
# 1	cretonesinho
# 1	electricidade
# 1	criadito
# 1	elasticidade
# 1	criadora
# 1	elaboravam
# 1	criancice
# 1	criancinhas
# 1	eira
# 1	egoístas
# 1	criara
# 1	egoísmos
# 1	criaria
# 1	egoisticamente
# 1	egiptologia
# 1	efémera
# 1	efusões
# 1	cricket
# 1	eficaz
# 1	efeminado
# 1	subissem
# 1	crina
# 1	efectivamente
# 1	eduquem
# 1	educoo
# 1	educo
# 1	criou
# 1	educasse
# 1	educar
# 1	educados
# 1	crista
# 1	cristãos
# 1	educa
# 1	edições
# 1	subirlhe
# 1	edifícios
# 1	edifício
# 1	edificação
# 1	edificar
# 1	edificante
# 1	edificadas
# 1	Apostar
# 1	Feri
# 1	economia
# 1	Festa
# 1	eclesiásticos
# 1	Fezme
# 1	eclesiástica
# 1	criticas
# 1	criticase
# 1	critério
# 1	crocodilo
# 1	croire
# 1	crosta
# 1	dúctil
# 1	dúcteis
# 1	crua
# 1	dístico
# 1	dêlhe
# 1	dêem
# 1	cruamente
# 1	démimonde
# 1	dégagè
# 1	cruzam
# 1	Fezselhes
# 1	débeis
# 1	dãome
# 1	cruzaram
# 1	dândismo
# 1	cruzarase
# 1	dávamos
# 1	dásme
# 1	subido
# 1	cruzasse
# 1	dálhe
# 1	dádivas
# 1	cruzavamse
# 1	cruzavao
# 1	cruzavaos
# 1	duvidou
# 1	duvido
# 1	cruzei
# 1	cruzeiros
# 1	duvidasinha
# 1	Apre
# 1	duvidando
# 1	durrante
# 1	cruzes
# 1	crápula
# 1	durmo
# 1	durindanas
# 1	crânios
# 1	duração
# 1	crâniosinho
# 1	virginais
# 1	duraria
# 1	durar
# 1	duraque
# 1	crê
# 1	duramente
# 1	duradoura
# 1	durabilidade
# 1	crítica
# 1	duquesas
# 1	Fiasco
# 1	duques
# 1	crítico
# 1	duples
# 1	subentendia
# 1	cubata
# 1	cuco
# 1	cuidadosa
# 1	dueto
# 1	subalternos
# 1	cuidar
# 1	ducado
# 1	culinária
# 1	dualismo
# 1	dualidade
# 1	subalternas
# 1	drogues
# 1	dreadful
# 1	dramático
# 1	dramaturgo
# 1	dramaticamente
# 1	dramas
# 1	dramalhões
# 1	dramalhão
# 1	culpada
# 1	dragonas
# 1	dragona
# 1	doçuras
# 1	culpado
# 1	culpas
# 1	doutro
# 1	doutrinários
# 1	cultivado
# 1	doutras
# 1	doutoral
# 1	cultora
# 1	cume
# 1	dourar
# 1	dourando
# 1	cumplicidade
# 1	cumplicidades
# 1	cumprimentada
# 1	cumprimentaram
# 1	douairière
# 1	dou
# 1	Ficamos
# 1	Ficaralhe
# 1	dose
# 1	cumprimentava
# 1	dorna
# 1	dormência
# 1	dormiu
# 1	cumprimento
# 1	Ficavam
# 1	Ficámos
# 1	cumprir
# 1	cumpriu
# 1	dorminhoco
# 1	cunhada
# 1	Figueira
# 1	curar
# 1	curara
# 1	dormi
# 1	curativos
# 1	dormem
# 1	curei
# 1	dorido
# 1	dorida
# 1	virgens
# 1	doravante
# 1	curro
# 1	dons
# 1	suada
# 1	cursi
# 1	Filandesas
# 1	donde
# 1	stá
# 1	donas
# 1	dona
# 1	domínios
# 1	domínio
# 1	Filho
# 1	curso
# 1	Filhos
# 1	Apresentou
# 1	curva
# 1	dominou
# 1	dominicano
# 1	dominicais
# 1	domingueiro
# 1	domingos
# 1	curvada
# 1	dominavam
# 1	stacato
# 1	dominar
# 1	vires
# 1	curvara
# 1	dominala
# 1	dominada
# 1	curvas
# 1	cuspido
# 1	custado
# 1	dom
# 1	custanos
# 1	ânsia
# 1	sportmen
# 1	custara
# 1	custava
# 1	dolo
# 1	custe
# 1	custoume
# 1	doirar
# 1	doiram
# 1	Filon
# 1	cuté
# 1	doidice
# 1	doidamente
# 1	cálido
# 1	dogmas
# 1	dogcarts
# 1	cândida
# 1	Filósofos
# 1	cândidos
# 1	cânfora
# 1	cântico
# 1	célebre
# 1	célula
# 1	céptico
# 1	documental
# 1	documentada
# 1	doctor
# 1	Finança
# 1	cérebro
# 1	círculos
# 1	cívica
# 1	cócegas
# 1	dobre
# 1	código
# 1	dobrasse
# 1	códigos
# 1	dobrar
# 1	dobrando
# 1	cóleras
# 1	cómico
# 1	cópias
# 1	dobleseis
# 1	doação
# 1	cós
# 1	diário
# 1	diáfana
# 1	virase
# 1	côdea
# 1	dizias
# 1	diziao
# 1	cônsul
# 1	cúpulas
# 1	dAlbe
# 1	sozinho
# 1	Aproveita
# 1	dArtagnan
# 1	dizerse
# 1	dizerre
# 1	dEscompte
# 1	dOrsay
# 1	dados
# 1	daguerreótipo
# 1	dizemme
# 1	sovado
# 1	sovada
# 1	dame
# 1	dizelhe
# 1	damos
# 1	danada
# 1	dix
# 1	dandolhes
# 1	dandose
# 1	divorciasse
# 1	dança
# 1	dançado
# 1	dançam
# 1	divindade
# 1	Finda
# 1	dançarina
# 1	danças
# 1	virandose
# 1	divida
# 1	divertiuos
# 1	soubeste
# 1	divertira
# 1	divertir
# 1	divertimentos
# 1	dardejava
# 1	divertidos
# 1	daremse
# 1	divertidas
# 1	darte
# 1	virandoa
# 1	divertese
# 1	diverte
# 1	diversos
# 1	diversas
# 1	diversamente
# 1	divergência
# 1	divagações
# 1	ditou
# 1	soubessem
# 1	dará
# 1	datada
# 1	dites
# 1	Findou
# 1	ditadura
# 1	ditadas
# 1	dita
# 1	souberamse
# 1	distúrbios
# 1	distâncias
# 1	datadas
# 1	distribuições
# 1	distribuição
# 1	distribuindo
# 1	distraímonos
# 1	datava
# 1	Finório
# 1	souber
# 1	davanos
# 1	distraia
# 1	Fiz
# 1	davase
# 1	distinção
# 1	distintos
# 1	deadbeat
# 1	distinta
# 1	distingués
# 1	debandar
# 1	distinguiu
# 1	distinguir
# 1	distinguiamse
# 1	distinguiam
# 1	debate
# 1	distingido
# 1	distinctas
# 1	distinctamente
# 1	distincta
# 1	distendido
# 1	debatera
# 1	debatiam
# 1	dissonância
# 1	debicavam
# 1	dissipou
# 1	dissipação
# 1	dissiparse
# 1	dissiparlhe
# 1	Fizemos
# 1	dissipado
# 1	dissipadas
# 1	dissipada
# 1	dissimulava
# 1	dissimulado
# 1	dissimulada
# 1	dissete
# 1	debilidade
# 1	dissessem
# 1	debilitante
# 1	dissese
# 1	debruçarse
# 1	disserao
# 1	disseramme
# 1	debruçou
# 1	debulhada
# 1	debute
# 1	dissemos
# 1	debutou
# 1	disselhes
# 1	decai
# 1	dissecandoas
# 1	decentes
# 1	dissabores
# 1	disputavam
# 1	disputandoa
# 1	dispusera
# 1	dispunha
# 1	disposto
# 1	soturnamente
# 1	virando
# 1	decidese
# 1	disposicion
# 1	dispor
# 1	dispondo
# 1	dispersões
# 1	decidi
# 1	dispersavam
# 1	dispersava
# 1	dispersara
# 1	dispersando
# 1	Fizeralhe
# 1	Aprovou
# 1	dispensava
# 1	dispensado
# 1	dispendioso
# 1	dispendiosa
# 1	disparatou
# 1	decidia
# 1	disparaselhe
# 1	disformes
# 1	Fizeramse
# 1	disfarçando
# 1	disfarçadamente
# 1	decididamente
# 1	disfarce
# 1	viragos
# 1	discutiuse
# 1	discutiu
# 1	discutisse
# 1	decididíssimo
# 1	viraas
# 1	discutimos
# 1	discutidas
# 1	discutida
# 1	decidindo
# 1	decidiram
# 1	decidiste
# 1	discute
# 1	discutamos
# 1	decifrando
# 1	declamamos
# 1	declamava
# 1	sossegando
# 1	discursar
# 1	Apóstolos
# 1	discriminações
# 1	declamou
# 1	declaralhe
# 1	declarando
# 1	discordância
# 1	discordavam
# 1	disciplinar
# 1	declarandolhe
# 1	discernir
# 1	dis
# 1	Foge
# 1	Aquiles
# 1	dirigiramse
# 1	dirigir
# 1	declaraste
# 1	dirigindo
# 1	dirigido
# 1	dirigidas
# 1	sossega
# 1	dirigia
# 1	declaravam
# 1	declaravas
# 1	declaravase
# 1	FoliesBergeres
# 1	direitas
# 1	declarações
# 1	declareilhe
# 1	declinações
# 1	decompondo
# 1	sorvido
# 1	sorvia
# 1	dire
# 1	dique
# 1	diplomáticas
# 1	sorveu
# 1	decorativas
# 1	diplomas
# 1	sorverlhe
# 1	dinheiros
# 1	decorativo
# 1	dinamite
# 1	diminuíssem
# 1	diminuía
# 1	diminuição
# 1	diminuir
# 1	dilúvio
# 1	diluída
# 1	diluir
# 1	diluindo
# 1	sorver
# 1	decoração
# 1	diletante
# 1	dilacerava
# 1	dilacerar
# 1	decoro
# 1	dilacerado
# 1	dilaceradas
# 1	dilacerada
# 1	decorreria
# 1	sorumbáticos
# 1	decotadas
# 1	dignitário
# 1	dignidades
# 1	decotado
# 1	dignasse
# 1	dignas
# 1	dignara
# 1	decotados
# 1	digeria
# 1	decotes
# 1	diganos
# 1	digamme
# 1	decrépita
# 1	decrépitos
# 1	decurso
# 1	dedicada
# 1	sorumbáticas
# 1	difuso
# 1	difusas
# 1	difusamente
# 1	difusa
# 1	diftéricas
# 1	dedicar
# 1	dedicarlhe
# 1	dificilmente
# 1	dedicarse
# 1	dedicavame
# 1	deduzia
# 1	difamante
# 1	deduzida
# 1	dicte
# 1	dicionário
# 1	dichotes
# 1	deduzira
# 1	deduziste
# 1	defeito
# 1	defeitos
# 1	diagnósticos
# 1	diabos
# 1	defende
# 1	defendendo
# 1	defendeu
# 1	defendia
# 1	sorumbática
# 1	dezasseis
# 1	dezanove
# 1	deferência
# 1	devoções
# 1	deficiência
# 1	definhar
# 1	definhava
# 1	devotamente
# 1	deformao
# 1	deformava
# 1	devorarte
# 1	devorar
# 1	devorandoo
# 1	defumadas
# 1	defumado
# 1	defuntas
# 1	degeneração
# 1	deviamno
# 1	degolada
# 1	deilhes
# 1	deviaa
# 1	deitadas
# 1	Fonte
# 1	For
# 1	deitados
# 1	deitara
# 1	deverrtido
# 1	deitaremno
# 1	deitarse
# 1	deveras
# 1	deitavase
# 1	devenu
# 1	deitei
# 1	deitem
# 1	deitoulhe
# 1	devastado
# 1	deitouse
# 1	devassidão
# 1	devassar
# 1	deixados
# 1	devagarinho
# 1	deixalo
# 1	deute
# 1	deixandoas
# 1	deuselhes
# 1	deixandolha
# 1	deixandoo
# 1	deulho
# 1	deixaraas
# 1	deuas
# 1	deixaralhe
# 1	deixavase
# 1	Foramno
# 1	detidamente
# 1	detevese
# 1	deixe
# 1	Formozelha
# 1	detestavam
# 1	deixeilhes
# 1	detestasse
# 1	sorrisinho
# 1	sorriramse
# 1	detestandoa
# 1	Arca
# 1	determinação
# 1	determinara
# 1	determinado
# 1	deteriorando
# 1	deterioradas
# 1	detendoo
# 1	deixemonos
# 1	deixemos
# 1	detalharlhe
# 1	detalhando
# 1	detalhadamcnte
# 1	detalhada
# 1	desço
# 1	desça
# 1	deixo
# 1	Forrça
# 1	desviavam
# 1	desviava
# 1	desviaram
# 1	desviar
# 1	desviandoa
# 1	desviando
# 1	desviado
# 1	desventuroso
# 1	desvelo
# 1	desvario
# 1	desvanecido
# 1	desvanecida
# 1	desvanecer
# 1	desvanecendose
# 1	desvairados
# 1	Fortuny
# 1	desvairada
# 1	desunião
# 1	destruirlhes
# 1	destruirlhe
# 1	destruiramse
# 1	sorrindolhes
# 1	destruidos
# 1	destroços
# 1	destroçada
# 1	destrezas
# 1	sorrindolhe
# 1	destoava
# 1	deixoua
# 1	deixouas
# 1	Foste
# 1	destinas
# 1	destinandoa
# 1	destinados
# 1	Fox
# 1	destinada
# 1	destilando
# 1	deixouse
# 1	desterro
# 1	desterrar
# 1	sorrialhes
# 1	deixássemos
# 1	dejame
# 1	sorrialhe
# 1	destapese
# 1	delambida
# 1	destampa
# 1	deleitar
# 1	destacavam
# 1	delgado
# 1	deliciada
# 1	destaca
# 1	deliciandose
# 1	delira
# 1	dessem
# 1	delirante
# 1	delirantes
# 1	delirara
# 1	desprotegida
# 1	despropósito
# 1	despropositou
# 1	despropositara
# 1	despropositar
# 1	Franca
# 1	desprezível
# 1	delírios
# 1	desprezando
# 1	desprezado
# 1	desprezada
# 1	desprevenido
# 1	desprendidos
# 1	demais
# 1	demandas
# 1	desprendendose
# 1	desprendendoo
# 1	Arcádia
# 1	despregara
# 1	despregar
# 1	despotismo
# 1	despontando
# 1	desplante
# 1	despiuse
# 1	despiu
# 1	despisse
# 1	despirse
# 1	despiriam
# 1	sorrateira
# 1	despindo
# 1	despilo
# 1	despido
# 1	despidas
# 1	France
# 1	despiam
# 1	despiaa
# 1	demasiadamente
# 1	demitamonos
# 1	despertouos
# 1	demitido
# 1	desperto
# 1	democrático
# 1	sordidamente
# 1	desperdício
# 1	despenteado
# 1	despenhara
# 1	despenhado
# 1	despenhadeiro
# 1	despender
# 1	democráticos
# 1	demorada
# 1	soprou
# 1	despeitada
# 1	despegavam
# 1	Frankfurt
# 1	despegara
# 1	despegar
# 1	despediuse
# 1	demorando
# 1	violoncelos
# 1	soprar
# 1	demorandose
# 1	demorarse
# 1	despedindose
# 1	despedindo
# 1	despedidos
# 1	soprandolhe
# 1	despediase
# 1	despediam
# 1	despedaçavao
# 1	despedaçara
# 1	despedaçando
# 1	despedaçado
# 1	despachos
# 1	despacharlhe
# 1	demoraste
# 1	despachado
# 1	desorientado
# 1	desorientada
# 1	desorganizou
# 1	Française
# 1	desordenados
# 1	desordenado
# 1	Frequentara
# 1	Frias
# 1	demoravam
# 1	Frio
# 1	desonra
# 1	desolavase
# 1	desolados
# 1	Friorenta
# 1	desolador
# 1	demorome
# 1	desoladamente
# 1	desolada
# 1	desocupado
# 1	desobstinada
# 1	desobedecerlhe
# 1	sonos
# 1	desnecessária
# 1	desmonte
# 1	desmantelava
# 1	desmancho
# 1	desmanchava
# 1	desmancharase
# 1	desmanchara
# 1	demónio
# 1	desmanchando
# 1	desmanchado
# 1	desmanchadamente
# 1	sonoros
# 1	Fugido
# 1	denominação
# 1	sonoridades
# 1	desmaiados
# 1	desmaiado
# 1	desmaiadas
# 1	Fugirmos
# 1	sonoras
# 1	deslumbrar
# 1	denso
# 1	deslumbrados
# 1	deslumbradora
# 1	dentada
# 1	deslocandose
# 1	deslocado
# 1	deslocada
# 1	deslizou
# 1	desligaria
# 1	desligada
# 1	desleixo
# 1	sonora
# 1	dentinhos
# 1	desleais
# 1	desjeitosamente
# 1	desistiu
# 1	desirmanadas
# 1	desinteresse
# 1	desinteressados
# 1	desinteressado
# 1	desinteressada
# 1	desinteligências
# 1	Fujamos
# 1	dentuça
# 1	sonolento
# 1	desiludidos
# 1	desiludido
# 1	desigual
# 1	desiguais
# 1	desguarnecido
# 1	denuncia
# 1	desgraçados
# 1	denunciando
# 1	desgraçadas
# 1	denunciava
# 1	departamento
# 1	depenado
# 1	desgostoso
# 1	depende
# 1	depender
# 1	desgostava
# 1	desgostasse
# 1	desgostaram
# 1	desfrizado
# 1	desfranzir
# 1	desforço
# 1	desforrarse
# 1	desforrar
# 1	desforrado
# 1	sonolenta
# 1	desfolhou
# 1	Fulana
# 1	desfolhada
# 1	desfizesse
# 1	desfilaram
# 1	dependia
# 1	Ardia
# 1	desfiam
# 1	desfezse
# 1	desfeitiara
# 1	desfeitas
# 1	Fulanos
# 1	desfeiassem
# 1	Fumava
# 1	desfazia
# 1	dependurados
# 1	dependurandoselhe
# 1	desfaz
# 1	desfavorável
# 1	dependurarselhe
# 1	desfalecesse
# 1	desfaleceram
# 1	desfalecendo
# 1	desesperos
# 1	dependurou
# 1	deplorável
# 1	desesperaraa
# 1	desesperara
# 1	desesperados
# 1	depositar
# 1	depositava
# 1	depravado
# 1	sonhem
# 1	depusera
# 1	depósitos
# 1	desequilibrada
# 1	desenxovalhada
# 1	desenxabido
# 1	desenxabida
# 1	desenvolvimentos
# 1	desenvolvimento
# 1	desenvolveu
# 1	desenvolver
# 1	desenterrava
# 1	desenroscarse
# 1	desenroscandose
# 1	desenrolou
# 1	desenrolavamse
# 1	desenrolavam
# 1	sonhei
# 1	Argélia
# 1	desenrolado
# 1	sonha
# 1	desenhando
# 1	desengonçavam
# 1	desengonçado
# 1	desengonça
# 1	desencontrados
# 1	desencaixotadas
# 1	desencadeara
# 1	desencadeado
# 1	desempenado
# 1	sonetos
# 1	desempacotar
# 1	desembrulhou
# 1	desembrulhava
# 1	desembrulhara
# 1	desembocou
# 1	desembocava
# 1	desembargadores
# 1	desembargador
# 1	desembarcou
# 1	Fume
# 1	desembarcados
# 1	desembaraçouse
# 1	desembaraçouo
# 1	desembaraçou
# 1	desembaraçate
# 1	desembaraçasse
# 1	desembaraçaria
# 1	deramlhe
# 1	desembaraçandose
# 1	desembaraçandoo
# 1	deramselhe
# 1	desejoulhe
# 1	derramando
# 1	derramandoa
# 1	derramar
# 1	desejei
# 1	derramou
# 1	desejaria
# 1	desejara
# 1	derreado
# 1	derreados
# 1	sondeia
# 1	desejada
# 1	deseja
# 1	derreia
# 1	derrete
# 1	desdobravase
# 1	desdobrava
# 1	desdobrarse
# 1	sondava
# 1	desdobrandose
# 1	desdobrando
# 1	Fusão
# 1	desdobrada
# 1	desdizse
# 1	desdiga
# 1	desdenhoso
# 1	desdenhosa
# 1	desdenhava
# 1	Futuro
# 1	derretese
# 1	Fé
# 1	desculpeme
# 1	derretido
# 1	desculpavase
# 1	desculpas
# 1	desculparse
# 1	desculpar
# 1	desculpandose
# 1	derrière
# 1	descuido
# 1	descuides
# 1	descuideime
# 1	somem
# 1	Ariano
# 1	descreveria
# 1	descreveram
# 1	descrevera
# 1	GRAND
# 1	descrevendolhe
# 1	descrevendo
# 1	descrevam
# 1	descreu
# 1	Gabelas
# 1	descrente
# 1	descosidas
# 1	derrocada
# 1	descorada
# 1	derrotas
# 1	des
# 1	desconsolarse
# 1	desconsolara
# 1	desconsolados
# 1	desconsoladoramente
# 1	Gafanha
# 1	sombrias
# 1	desabafa
# 1	desabafadamente
# 1	desabalado
# 1	desconsideração
# 1	desconhecidos
# 1	desconhecido
# 1	Gago
# 1	desabitada
# 1	desconfiou
# 1	desconfio
# 1	Gainsborough
# 1	desconfiados
# 1	desabridas
# 1	desconfiadamente
# 1	desabrigada
# 1	desconfia
# 1	desconcertar
# 1	desconcertado
# 1	descompostura
# 1	descomposto
# 1	descomposta
# 1	descolava
# 1	Galgou
# 1	desabrocha
# 1	descobrisse
# 1	descobriria
# 1	desacordo
# 1	desacreditado
# 1	Galileia
# 1	descobriam
# 1	somado
# 1	Galileu
# 1	Gamacho
# 1	descobertos
# 1	desafiados
# 1	descobertas
# 1	desafinado
# 1	solzinho
# 1	desafinar
# 1	descidas
# 1	desafinavam
# 1	desafiou
# 1	desafivelar
# 1	desceuse
# 1	desafogada
# 1	descesse
# 1	solva
# 1	descerrarlhe
# 1	descerrar
# 1	desceramno
# 1	desafogados
# 1	Gamas
# 1	desafogando
# 1	soluçou
# 1	desafogar
# 1	descendia
# 1	descendessem
# 1	descemos
# 1	desafogo
# 1	desafogou
# 1	descaídas
# 1	descaída
# 1	descaíamlhe
# 1	descascava
# 1	descarregando
# 1	descaro
# 1	descarnado
# 1	descarado
# 1	descarada
# 1	descansou
# 1	desagradava
# 1	desagradavelmente
# 1	descansadamente
# 1	descansa
# 1	descambara
# 1	descambar
# 1	descalço
# 1	descalçava
# 1	descalçando
# 1	descalçado
# 1	descaiuse
# 1	descaiu
# 1	descair
# 1	desbotados
# 1	desbotado
# 1	desbotada
# 1	desbocada
# 1	Garret
# 1	desavergonhado
# 1	desavergonhadas
# 1	desavergonhada
# 1	desatrelado
# 1	desatravancado
# 1	desagradou
# 1	desatenção
# 1	desatado
# 1	desata
# 1	desagradoulhe
# 1	desajeitados
# 1	desassossegar
# 1	desassossegado
# 1	desalento
# 1	desarrolhando
# 1	desarranjo
# 1	desalinhado
# 1	desarmonia
# 1	Gasta
# 1	desamorável
# 1	desapontado
# 1	desapontada
# 1	desanimadora
# 1	desapertava
# 1	desapertara
# 1	desapertando
# 1	desapertada
# 1	desapercebido
# 1	desaparelhar
# 1	desaparecimentos
# 1	Gautier
# 1	desaparecidos
# 1	desanuviar
# 1	desaparecida
# 1	desaparecer
# 1	soluçar
# 1	soluçantes
# 1	Gemia
# 1	Geral
# 1	Gladiador
# 1	Globo
# 1	Aristocracia
# 1	solteirona
# 1	Arles
# 1	God
# 1	violenta
# 1	Godefroy
# 1	soltasse
# 1	Goncourt
# 1	óperacómica
# 1	Goodbye
# 1	Goodwood
# 1	soltado
# 1	Gordinha
# 1	Gosta
# 1	Gota
# 1	Governo
# 1	vio
# 1	Grachos
# 1	Gramont
# 1	Granada
# 1	solidário
# 1	vinténs
# 1	vintista
# 1	solidamente
# 1	Arménia
# 1	Grand
# 1	solicitara
# 1	soletrar
# 1	soleníssimo
# 1	solenidades
# 1	GrandPrix
# 1	GrandTreize
# 1	Arquitecto
# 1	Granja
# 1	sole
# 1	Gray
# 1	Gregos
# 1	solavancos
# 1	solas
# 1	solar
# 1	sola
# 1	Greuze
# 1	Grinalda
# 1	Guarda
# 1	Guardea
# 1	sogra
# 1	Guilherme
# 1	Guimarini
# 1	sofríamos
# 1	Arranjaramse
# 1	Guimarof
# 1	vinhedos
# 1	sofridas
# 1	sofriase
# 1	sofriam
# 1	Guinava
# 1	vinhaça
# 1	sofreria
# 1	sofrera
# 1	Guiné
# 1	1858
# 1	Gustavo
# 1	Género
# 1	vinhamse
# 1	sofra
# 1	soez
# 1	soes
# 1	HOTEL
# 1	socos
# 1	Arranjase
# 1	sociável
# 1	sociedadesinha
# 1	Habitavam
# 1	Habitável
# 1	vinhalhe
# 1	socialismo
# 1	Havemos
# 1	Haviaos
# 1	Arranje
# 1	Heidelhe
# 1	vingou
# 1	vingarse
# 1	sobriamente
# 1	Helas
# 1	sobressaíam
# 1	sobressaltos
# 1	Heliogábalo
# 1	sobressaltadas
# 1	sobrescritos
# 1	Heloisa
# 1	sobrescritado
# 1	sobrescritada
# 1	sobrepostos
# 1	sobrenatural
# 1	Helvetius
# 1	Helène
# 1	sobrecarregar
# 1	sobrecarregadas
# 1	Henrique
# 1	sobraçou
# 1	sobraçava
# 1	sobravalhe
# 1	sobrava
# 1	sobranceria
# 1	Herança
# 1	Herbert
# 1	Highlifes
# 1	Histórias
# 1	soberbamente
# 1	Históricos
# 1	soberanos
# 1	soberano
# 1	soberanamente
# 1	sobem
# 1	sobelhe
# 1	sobe
# 1	Hombre
# 1	soava
# 1	Abandonaste
# 1	Arranjou
# 1	Hora
# 1	soalheiro
# 1	soalheiras
# 1	soalheira
# 1	soa
# 1	ásperos
# 1	slécht
# 1	sleepingcar
# 1	situações
# 1	Horrível
# 1	situada
# 1	sisudo
# 1	vindolhe
# 1	sistemas
# 1	Horácio
# 1	sirvase
# 1	sirva
# 1	sirigaita
# 1	Houvera
# 1	sintético
# 1	sintome
# 1	sintomas
# 1	sintoma
# 1	Huguenotes
# 1	Arrastate
# 1	Humano
# 1	sino
# 1	Humores
# 1	singularmente
# 1	Háde
# 1	singelas
# 1	Arrastou
# 1	sinfonia
# 1	Hãodese
# 1	II
# 1	IV
# 1	sinceros
# 1	Iago
# 1	Ibero
# 1	vincos
# 1	vincada
# 1	Arraz
# 1	sinalsinho
# 1	Ideal
# 1	Idealistas
# 1	simultânea
# 1	simulada
# 1	simpáticos
# 1	Igrejas
# 1	Ih
# 1	simplório
# 1	vimonos
# 1	Ilhas
# 1	simpleza
# 1	Ilustrado
# 1	Imagem
# 1	simpatizara
# 1	simpatizar
# 1	simpaticamente
# 1	vime
# 1	Imagens
# 1	similitudes
# 1	Arrebatadamente
# 1	Imaginam
# 1	simbólicos
# 1	Arrebatou
# 1	simbolizasse
# 1	simbolizando
# 1	Imaginara
# 1	Imaginaram
# 1	Imaginase
# 1	silvos
# 1	silvo
# 1	vilipendiar
# 1	Imaginasse
# 1	silvavam
# 1	silvar
# 1	silvante
# 1	silenciosos
# 1	Imaginavao
# 1	Imaginavas
# 1	Imaginem
# 1	Imaginámos
# 1	silence
# 1	sigo
# 1	Imensa
# 1	Abandoneia
# 1	significativamente
# 1	Arredondava
# 1	Imenso
# 1	siga
# 1	Impaciente
# 1	sicrano
# 1	sibilinas
# 1	Imperial
# 1	Implicaram
# 1	Arruinado
# 1	Inapreciável
# 1	shakehand
# 1	shake
# 1	1870
# 1	sextafeira
# 1	Incomodavao
# 1	Incomodo
# 1	Incontestavelmente
# 1	Indecente
# 1	vigorosamente
# 1	Indivíduos
# 1	Indo
# 1	Infante
# 1	Informações
# 1	Inglesa
# 1	vigor
# 1	Inimigo
# 1	Injuriava
# 1	ses
# 1	seríamos
# 1	Inquieto
# 1	seráfica
# 1	Instalado
# 1	servo
# 1	Instalas
# 1	Instinctivamente
# 1	vigilante
# 1	vigiava
# 1	servisse
# 1	servirte
# 1	Artof
# 1	Instintivamente
# 1	Inteligência
# 1	Intendente
# 1	vigas
# 1	Interessouse
# 1	servidas
# 1	servida
# 1	service
# 1	Intimamente
# 1	serviaa
# 1	Intitulavase
# 1	serves
# 1	Inverno
# 1	servem
# 1	Inútil
# 1	sertão
# 1	serranias
# 1	Iria
# 1	serradura
# 1	Irmão
# 1	Irmãs
# 1	serpentina
# 1	serpeavam
# 1	vieux
# 1	sermos
# 1	seriosinho
# 1	seringou
# 1	seriissima
# 1	Irresistivelmente
# 1	serias
# 1	Isaias
# 1	Abandono
# 1	Isolabela
# 1	serge
# 1	Isolouse
# 1	sereníssima
# 1	serenou
# 1	Italiano
# 1	Jai
# 1	serenata
# 1	Jambon
# 1	Jantar
# 1	Jantaram
# 1	Janto
# 1	serafim
# 1	sera
# 1	Jardim
# 1	sequioso
# 1	sequiosa
# 1	Jeane
# 1	viesses
# 1	Jerusalém
# 1	sepultouse
# 1	sepultoua
# 1	Abanouse
# 1	sepultasse
# 1	sepultarse
# 1	sepultado
# 1	sepulcro
# 1	separouse
# 1	separei
# 1	Jerónimo
# 1	separavamse
# 1	Asco
# 1	Jerónimos
# 1	separarse
# 1	separarnos
# 1	separarmos
# 1	separara
# 1	Jesuítas
# 1	separam
# 1	Joaquina
# 1	Job
# 1	vieramlhe
# 1	separada
# 1	separa
# 1	Jogase
# 1	Jogo
# 1	Jogou
# 1	Assaltoume
# 1	sentiuo
# 1	Johanes
# 1	sentissem
# 1	Jornadas
# 1	sentirlhes
# 1	sentirem
# 1	Jovelos
# 1	Juanito
# 1	Juca
# 1	Judas
# 1	Judit
# 1	sentindoo
# 1	sentindoa
# 1	Judith
# 1	Jules
# 1	Julgava
# 1	Assinavase
# 1	sentimentalismo
# 1	Julinha
# 1	Assomoir
# 1	sentilo
# 1	sentilahia
# 1	Juntaramse
# 1	Juro
# 1	vienenses
# 1	viendrait
# 1	sentialhes
# 1	sentiaa
# 1	Juroto
# 1	Abecê
# 1	sentes
# 1	sentemse
# 1	Justa
# 1	Assustada
# 1	vie
# 1	sentasse
# 1	sentarselhes
# 1	Justos
# 1	Khiva
# 1	Assustado
# 1	Atabalhoara
# 1	Klopstock
# 1	Laborde
# 1	Lacordaire
# 1	Laferme
# 1	Laferrière
# 1	sensível
# 1	sensualidade
# 1	Abegoaria
# 1	Lagartijo
# 1	sensibilizouse
# 1	Atireilhe
# 1	sensibilidades
# 1	sensações
# 1	Lagoaça
# 1	Atirouo
# 1	sensatamente
# 1	árias
# 1	sensaborões
# 1	Lamarck
# 1	senil
# 1	vidinha
# 1	senhoril
# 1	Lamentável
# 1	Lamêgo
# 1	Landim
# 1	Landseer
# 1	senhasinha
# 1	senhas
# 1	senha
# 1	Lançarase
# 1	senda
# 1	senadores
# 1	Larga
# 1	sempiterna
# 1	seminudez
# 1	seminuas
# 1	semelhanças
# 1	vide
# 1	Largaraa
# 1	semeado
# 1	Largas
# 1	Largoua
# 1	Lausperene
# 1	Lazareto
# 1	Le
# 1	Legado
# 1	selva
# 1	Atlântico
# 1	selar
# 1	selado
# 1	viciosos
# 1	sejes
# 1	Leia
# 1	sejamos
# 1	viciosas
# 1	Leis
# 1	seixos
# 1	seiva
# 1	vicejante
# 1	Lembrame
# 1	vicecônsul
# 1	Atravessando
# 1	Lembrarase
# 1	Lenta
# 1	seguros
# 1	Lentamente
# 1	Atravessaram
# 1	segurar
# 1	Leonor
# 1	vibravam
# 1	vibrava
# 1	Les
# 1	Leste
# 1	Levamos
# 1	seguiuos
# 1	seguiulhe
# 1	seguiua
# 1	Levanteime
# 1	seguiste
# 1	Atreve
# 1	seguirão
# 1	seguiriam
# 1	seguirem
# 1	Levantouse
# 1	Atribuindo
# 1	Levava
# 1	seguintes
# 1	Levavam
# 1	seguindoa
# 1	Levemente
# 1	seguilo
# 1	1872
# 1	Levoo
# 1	Levou
# 1	viação
# 1	seguiamse
# 1	Levouos
# 1	Leão
# 1	seguem
# 1	segue
# 1	Atroz
# 1	Li
# 1	Liberal
# 1	segredinhos
# 1	segredar
# 1	segredando
# 1	Liberalismo
# 1	seduções
# 1	vias
# 1	seduziu
# 1	seduzira
# 1	Libertaramse
# 1	seduzia
# 1	seductor
# 1	Liceu
# 1	sedativa
# 1	Lindor
# 1	Lindíssimo
# 1	secção
# 1	Liverpool
# 1	ódiosinho
# 1	secular
# 1	viamna
# 1	secretos
# 1	viame
# 1	secretas
# 1	secretarías
# 1	Livingstone
# 1	Liviosinho
# 1	Livro
# 1	secretamente
# 1	Lobo
# 1	Lolas
# 1	Longas
# 1	secase
# 1	Longos
# 1	secarase
# 1	secandolhe
# 1	Atêrro
# 1	LordMaire
# 1	vialhe
# 1	Louvre
# 1	sebáceo
# 1	sebácea
# 1	Lubin
# 1	sebes
# 1	Lucas
# 1	viajou
# 1	season
# 1	searas
# 1	Lucrécia
# 1	saúdes
# 1	Lucy
# 1	saíste
# 1	Lutei
# 1	saírase
# 1	Austerlitz
# 1	saíralhe
# 1	Luz
# 1	saímos
# 1	saídos
# 1	Lêrao
# 1	saídas
# 1	Lêselhe
# 1	Austrália
# 1	Lógica
# 1	saí
# 1	saxónio
# 1	saxonias
# 1	save
# 1	Abissínia
# 1	saudáveis
# 1	saudála
# 1	MARIA
# 1	MARTYRIO
# 1	saudosas
# 1	saudosamente
# 1	Macaulay
# 1	áleas
# 1	saudavamse
# 1	saudar
# 1	Madalena
# 1	viajam
# 1	Mademoiselle
# 1	Magalhães
# 1	viajado
# 1	Magestade
# 1	satisfez
# 1	Magnificente
# 1	satisfeitas
# 1	satisfeita
# 1	satisfações
# 1	Magno
# 1	AveMaria
# 1	Magnífico
# 1	satisfactoriamente
# 1	sarrabulhada
# 1	sarna
# 1	Magoasteme
# 1	Maio
# 1	Maisonetes
# 1	sarcástico
# 1	sarcasticamente
# 1	sarcasmos
# 1	sarcasmo
# 1	Mala
# 1	sarampo
# 1	Malibran
# 1	sapos
# 1	sapatões
# 1	Mandalhe
# 1	Mandarao
# 1	sapatinhos
# 1	sapatinho
# 1	santé
# 1	santuários
# 1	Mandarme
# 1	Mandarte
# 1	Mandei
# 1	Mandeia
# 1	santas
# 1	Mandeme
# 1	sanguíneo
# 1	Mandervile
# 1	sangrias
# 1	sangrentos
# 1	Manfredo
# 1	Manoela
# 1	sandwich
# 1	sandices
# 1	sanctuário
# 1	salõesdançantes
# 1	Manoeleta
# 1	Manual
# 1	salvou
# 1	salvese
# 1	Aventura
# 1	Azambuja
# 1	BOULEVARD
# 1	salvas
# 1	Manuelzinho
# 1	salvam
# 1	salvadora
# 1	Maquinalmente
# 1	Maravilhosa
# 1	Marcos
# 1	saltitando
# 1	salteador
# 1	Babel
# 1	Bach
# 1	saltaram
# 1	Bacharéis
# 1	Margaridas
# 1	Marignan
# 1	saltado
# 1	Marios
# 1	salpicar
# 1	salpicandoo
# 1	Marselha
# 1	salpicada
# 1	vexame
# 1	saloias
# 1	saloia
# 1	ódios
# 1	álcoois
# 1	salientes
# 1	salgado
# 1	Marselhas
# 1	1886
# 1	Martes
# 1	salame
# 1	Martírios
# 1	álbum
# 1	Matadouro
# 1	Matalo
# 1	sairá
# 1	sairse
# 1	sairia
# 1	Matasete
# 1	saio
# 1	saindolhe
# 1	Matriculouse
# 1	Mauricio
# 1	Maximiliano
# 1	Mayfair
# 1	saialhe
# 1	Mazas
# 1	Maçonaria
# 1	saguões
# 1	saguão
# 1	Meditação
# 1	Medonho
# 1	Bad
# 1	sagas
# 1	safou
# 1	vestígio
# 1	safarte
# 1	safarse
# 1	safarme
# 1	safar
# 1	safada
# 1	sadios
# 1	sacudiuo
# 1	Meia
# 1	sacudirmonos
# 1	sacudirme
# 1	MeiaIdade
# 1	sacudindolhas
# 1	sacudindoa
# 1	Melchiorzinho
# 1	vestuário
# 1	águias
# 1	sacudida
# 1	sacudiao
# 1	Melhor
# 1	sacudialhe
# 1	Melhores
# 1	sacré
# 1	Melodias
# 1	sacrosanto
# 1	Menant
# 1	Menciono
# 1	Mendelhson
# 1	sacrifico
# 1	sacrificas
# 1	vestiu
# 1	sacrifica
# 1	Bagdad
# 1	sacoroto
# 1	sacola
# 1	sacode
# 1	Mendelsshon
# 1	Mera
# 1	saciara
# 1	vestirnos
# 1	sacarei
# 1	sacada
# 1	Merv
# 1	sabujices
# 1	vestiram
# 1	sabuja
# 1	Messageries
# 1	saborsinho
# 1	saboreou
# 1	saboreava
# 1	saboreando
# 1	Messias
# 1	sabonete
# 1	Mesão
# 1	vestira
# 1	sabiao
# 1	sabiamente
# 1	Mete
# 1	sabiaa
# 1	Meteram
# 1	Baia
# 1	Meteua
# 1	saberá
# 1	Mexeu
# 1	Milionário
# 1	Milo
# 1	sabendoo
# 1	Milão
# 1	sabemos
# 1	Minhalma
# 1	Ministro
# 1	Mirabeau
# 1	sabeis
# 1	sabedoria
# 1	Misericórdia
# 1	Bailavalhe
# 1	Mistérios
# 1	rústico
# 1	rústica
# 1	rôta
# 1	ríspido
# 1	vestimenta
# 1	Mmede
# 1	Moderna
# 1	Bairrada
# 1	Baixou
# 1	Abracemse
# 1	rés
# 1	réps
# 1	réplica
# 1	Molhavalhe
# 1	Balbuciava
# 1	águaráz
# 1	vestiam
# 1	Mon
# 1	rápida
# 1	Montanha
# 1	Montar
# 1	Montenegro
# 1	Monção
# 1	Balbuciou
# 1	russo
# 1	águar
# 1	runing
# 1	rumorosas
# 1	rumorosa
# 1	Morrer
# 1	Morrera
# 1	veste
# 1	ruminara
# 1	ruminar
# 1	ruminante
# 1	vesgos
# 1	rum
# 1	Morreute
# 1	ruivo
# 1	Morrisson
# 1	verídico
# 1	ruidosos
# 1	Moscovo
# 1	Mourão
# 1	Moçambique
# 1	rugosas
# 1	Moço
# 1	rugir
# 1	rugindo
# 1	rugidos
# 1	Baltresqui
# 1	Abraçaramse
# 1	Moços
# 1	MuciosScevolas
# 1	rufava
# 1	verá
# 1	rudes
# 1	Mudaram
# 1	very
# 1	rubrica
# 1	ruborzinho
# 1	ruborizavamse
# 1	Mudase
# 1	Bancos
# 1	ruazinha
# 1	ruasita
# 1	Mulheres
# 1	Muralha
# 1	Murmurou
# 1	roídos
# 1	vertigens
# 1	roída
# 1	roíao
# 1	roçou
# 1	vertigem
# 1	roçavalhe
# 1	roçava
# 1	roçasse
# 1	roçarem
# 1	roçara
# 1	Murmúrios
# 1	Má
# 1	roçandolhe
# 1	Málaga
# 1	roçado
# 1	verticais
# 1	Mártir
# 1	ágeis
# 1	Mártires
# 1	Mónaco
# 1	rouquejou
# 1	roupões
# 1	Móvel
# 1	Músculo
# 1	Nababo
# 1	Namorarase
# 1	ádito
# 1	roucos
# 1	Nantes
# 1	Napoléon
# 1	roubo
# 1	roubar
# 1	roubada
# 1	rotundo
# 1	Banda
# 1	Bandalhismo
# 1	rotineiro
# 1	rotineiras
# 1	versinhos
# 1	rota
# 1	rosário
# 1	verselhe
# 1	ácida
# 1	Naquelas
# 1	rosse
# 1	rosquinha
# 1	rosnoulhe
# 1	Naquele
# 1	Barbedo
# 1	rosnara
# 1	Nascera
# 1	Nasceste
# 1	rosnada
# 1	rosna
# 1	rosinhas
# 1	rosetas
# 1	roseta
# 1	roseou
# 1	Nasci
# 1	roseira
# 1	roscas
# 1	Natais
# 1	vers
# 1	rosado
# 1	Natal
# 1	Nature
# 1	roquesinho
# 1	ronronava
# 1	ronha
# 1	verosímil
# 1	Nauseado
# 1	Naval
# 1	Nebulosas
# 1	ronco
# 1	Abraçou
# 1	roncava
# 1	roncantes
# 1	romã
# 1	Necessitava
# 1	Necessitavam
# 1	Negociosinho
# 1	Negrejava
# 1	Negócios
# 1	rompiam
# 1	Nervoso
# 1	rompeulhe
# 1	Nesle
# 1	rompesse
# 1	romperem
# 1	Nestas
# 1	Nicolini
# 1	vernizes
# 1	Nihilismo
# 1	rompe
# 1	rompante
# 1	romarias
# 1	Barroso
# 1	romanzeiras
# 1	romanza
# 1	romantizes
# 1	romantismos
# 1	Nihilistas
# 1	romanticamente
# 1	Baspt
# 1	romano
# 1	Ninho
# 1	romanesca
# 1	romancista
# 1	romancesinho
# 1	Ninive
# 1	Nisto
# 1	vermos
# 1	Nobiliário
# 1	Norma
# 1	Bastame
# 1	Normandia
# 1	roliço
# 1	roliças
# 1	Notou
# 1	rolhas
# 1	vermelhão
# 1	roleta
# 1	rolem
# 1	roldão
# 1	NotreDame
# 1	Noutra
# 1	rolaremlhe
# 1	Noutro
# 1	Noutros
# 1	NovaOrleans
# 1	rolalo
# 1	Novamente
# 1	rojavam
# 1	rojam
# 1	rogou
# 1	rogando
# 1	rogalhe
# 1	roer
# 1	roendo
# 1	Novidade
# 1	rodos
# 1	rodo
# 1	rodelas
# 1	rodela
# 1	rodeavam
# 1	rodeado
# 1	Bastante
# 1	Numero
# 1	Numerosos
# 1	rodapé
# 1	Bastava
# 1	Nunciatura
# 1	rococós
# 1	rococó
# 1	rochedos
# 1	rochas
# 1	Nuvem
# 1	robustíssimos
# 1	Nº
# 1	Nú
# 1	robles
# 1	roble
# 1	Núncio
# 1	1887
# 1	robbers
# 1	robber
# 1	roastbeef
# 1	riçado
# 1	rixa
# 1	rivalidade
# 1	rivais
# 1	OIivais
# 1	Obedecendo
# 1	riste
# 1	risse
# 1	risota
# 1	Obras
# 1	Ocupavase
# 1	Odes
# 1	Odiando
# 1	Odiavao
# 1	risinhos
# 1	Odiou
# 1	risco
# 1	vermelhejavamlhe
# 1	vermelhejava
# 1	vermelhejando
# 1	riscadinho
# 1	riscada
# 1	Odivelas
# 1	Bate
# 1	Oficial
# 1	Olhame
# 1	ris
# 1	riram
# 1	rira
# 1	Olimpo
# 1	riquezas
# 1	Operário
# 1	Bateram
# 1	verlhes
# 1	Opinião
# 1	Bateu
# 1	Opressão
# 1	rinche
# 1	rimos
# 1	Orango
# 1	Beaucoup
# 1	rilhava
# 1	Orenoque
# 1	rilhados
# 1	Bebe
# 1	Organizara
# 1	rija
# 1	verificando
# 1	Orsay
# 1	Oton
# 1	rifada
# 1	rien
# 1	riemse
# 1	ridículos
# 1	Oui
# 1	veriam
# 1	Bebia
# 1	rido
# 1	Ousou
# 1	Ouvese
# 1	Ouviralhe
# 1	vergões
# 1	Ouviu
# 1	ribombar
# 1	ribeiro
# 1	vergou
# 1	Ouço
# 1	Oxford
# 1	PENDENCIA
# 1	reúnem
# 1	rezingão
# 1	rezes
# 1	rezava
# 1	rezas
# 1	rezarlhe
# 1	Bebiase
# 1	PS
# 1	revólver
# 1	revés
# 1	revolvia
# 1	revolveuo
# 1	vergavamse
# 1	Padres
# 1	revolucionários
# 1	vergavam
# 1	vergava
# 1	revolucionaria
# 1	revoltouse
# 1	revoltos
# 1	vergastas
# 1	revolteando
# 1	revoltados
# 1	vergastar
# 1	Pai
# 1	Paixão
# 1	revoada
# 1	reviveu
# 1	revivera
# 1	Pale
# 1	revivendo
# 1	revista
# 1	revisitar
# 1	revirouo
# 1	revirou
# 1	revirando
# 1	reviralo
# 1	reviradas
# 1	Palha
# 1	revestirao
# 1	revestir
# 1	revestimento
# 1	vergastando
# 1	Beijoulhe
# 1	vergando
# 1	reverente
# 1	reverendos
# 1	Palmas
# 1	reverenciar
# 1	reverberações
# 1	rever
# 1	àqueles
# 1	revelou
# 1	Palmela
# 1	Palmita
# 1	Abraçoua
# 1	Palácio
# 1	revelasse
# 1	revelarse
# 1	revelarase
# 1	revelaram
# 1	revelaralhe
# 1	revelara
# 1	àquelas
# 1	Panamá
# 1	Abraçouo
# 1	revelada
# 1	vereador
# 1	Bele
# 1	reunirse
# 1	reunirnos
# 1	Belfast
# 1	reuniram
# 1	Pancho
# 1	reunindo
# 1	reunia
# 1	Benan
# 1	Pandoli
# 1	retórico
# 1	Panorama
# 1	retêla
# 1	retumbou
# 1	retumbavam
# 1	retumbar
# 1	retumbantemente
# 1	retrós
# 1	Pansa
# 1	retrocedera
# 1	retroceder
# 1	retratosinho
# 1	Papado
# 1	Papas
# 1	Abrilada
# 1	retractarse
# 1	retracta
# 1	retortas
# 1	retorcido
# 1	retorcer
# 1	retorcendose
# 1	verdenegra
# 1	retorce
# 1	Papel
# 1	Benefícios
# 1	Parara
# 1	retomará
# 1	Óptimo
# 1	retomar
# 1	retomandolhe
# 1	verdegarrafa
# 1	Parecera
# 1	retocava
# 1	verdeescuros
# 1	verdeescuro
# 1	Pareceralhe
# 1	retiravase
# 1	retirava
# 1	retirasse
# 1	Ópera
# 1	retiraramse
# 1	Pareceste
# 1	Pareceu
# 1	retirandolho
# 1	retirados
# 1	Pareceulhe
# 1	Pareciam
# 1	retira
# 1	retintas
# 1	retinta
# 1	Pares
# 1	retinia
# 1	retinham
# 1	retinha
# 1	Parfaitement
# 1	retidas
# 1	reticências
# 1	reticência
# 1	reteveos
# 1	reteveo
# 1	reteve
# 1	reteso
# 1	retesando
# 1	retesados
# 1	retesadas
# 1	Parlamentares
# 1	retendoo
# 1	retendoa
# 1	retemperarnos
# 1	retardouse
# 1	retardou
# 1	retardasse
# 1	retardaram
# 1	retardando
# 1	verdeclaros
# 1	retardada
# 1	resvalou
# 1	Bertoni
# 1	resvalara
# 1	resvalando
# 1	resumos
# 1	Parma
# 1	Parte
# 1	resumindo
# 1	resumia
# 1	resultou
# 1	resultando
# 1	Partenon
# 1	resulta
# 1	Partimos
# 1	Partiu
# 1	restituísse
# 1	restituirlhos
# 1	restituir
# 1	restituindolhe
# 1	restavamlhe
# 1	Parto
# 1	Passa
# 1	restaurante
# 1	restaria
# 1	restar
# 1	restabelecido
# 1	restabelecida
# 1	restabelecer
# 1	Passadas
# 1	ressuscitar
# 1	ressuscita
# 1	ressurreição
# 1	verdadesinhas
# 1	ressurgir
# 1	Absoluto
# 1	ressurgia
# 1	ressudando
# 1	Passame
# 1	Passando
# 1	Passaramse
# 1	Bertrand
# 1	Passase
# 1	ressoantes
# 1	ressequindo
# 1	Biblioteca
# 1	ressequidas
# 1	ressentiu
# 1	verdadeiras
# 1	ressentido
# 1	ressentem
# 1	ressalvar
# 1	ressaltou
# 1	Passavam
# 1	Passavamse
# 1	Passavase
# 1	responsável
# 1	responsáveis
# 1	responsabilité
# 1	Passeava
# 1	Passei
# 1	respondido
# 1	Bignon
# 1	respondialhe
# 1	Passeia
# 1	respondi
# 1	Passoulhe
# 1	responderam
# 1	Patagónia
# 1	Patrick
# 1	Biscainha
# 1	responde
# 1	respondas
# 1	Blague
# 1	Patrício
# 1	Paulino
# 1	resplandeceram
# 1	Paus
# 1	resplandecentes
# 1	Pautas
# 1	resplandecendo
# 1	respirálo
# 1	Pecara
# 1	Pedante
# 1	respiravam
# 1	Pedeme
# 1	respirase
# 1	respiraram
# 1	Pedir
# 1	Pediulhe
# 1	respira
# 1	Pedra
# 1	respeitoulhe
# 1	respeitoso
# 1	Pegaramse
# 1	respeitosa
# 1	Peixotos
# 1	Pelas
# 1	respeitavaa
# 1	respeitava
# 1	respeitas
# 1	respeitar
# 1	respeitado
# 1	respeitada
# 1	verbosidade
# 1	Êtesvous
# 1	resolvidas
# 1	resolvida
# 1	resolviase
# 1	resolviam
# 1	resolvi
# 1	Acabou
# 1	Pelase
# 1	resolver
# 1	resolvendose
# 1	resolvendo
# 1	resolve
# 1	resoluções
# 1	Pelicano
# 1	Blanc
# 1	veras
# 1	Pendia
# 1	Block
# 1	Éliseés
# 1	Éclogas
# 1	Penedo
# 1	resistiu
# 1	resistiria
# 1	resistira
# 1	resistir
# 1	resistindo
# 1	resistia
# 1	resisti
# 1	ventresinho
# 1	resinas
# 1	Penetraram
# 1	Blond
# 1	Penetrava
# 1	ventos
# 1	BoaHora
# 1	residências
# 1	Pensa
# 1	resguardo
# 1	resguardavam
# 1	resguardava
# 1	resguardando
# 1	resguardados
# 1	resguardado
# 1	resfolgar
# 1	resfolegava
# 1	reservava
# 1	reservados
# 1	Pensamentos
# 1	reservada
# 1	Pensando
# 1	rescendente
# 1	rescendendo
# 1	Pensar
# 1	Pensara
# 1	requintava
# 1	Pensativa
# 1	requintadas
# 1	requentando
# 1	requebros
# 1	requebro
# 1	requebrando
# 1	Pensava
# 1	repuxou
# 1	repuxos
# 1	Percebeu
# 1	ventas
# 1	venta
# 1	repulsão
# 1	repulsivo
# 1	Percebi
# 1	repugnoulhe
# 1	repugnavalhe
# 1	repugnava
# 1	Bocejando
# 1	Perdera
# 1	Perdida
# 1	Pereiro
# 1	reprovável
# 1	reprovado
# 1	reprimir
# 1	represália
# 1	venhome
# 1	Bolacha
# 1	representar
# 1	Bolsa
# 1	Pergunta
# 1	representam
# 1	representado
# 1	representa
# 1	Perguntara
# 1	repreensivo
# 1	repreendiao
# 1	repreendeua
# 1	repreendesse
# 1	Aceitar
# 1	Perguntasse
# 1	repousava
# 1	repousar
# 1	repousante
# 1	repousandolhe
# 1	repousando
# 1	Perseverança
# 1	Pertence
# 1	repossuir
# 1	reportórios
# 1	repoltreouse
# 1	repoltreado
# 1	Pertencendo
# 1	replicava
# 1	repita
# 1	repisar
# 1	Peruanos
# 1	repintados
# 1	repicou
# 1	repicavam
# 1	repicava
# 1	Bonito
# 1	Pesadote
# 1	venezianas
# 1	repetiram
# 1	repetira
# 1	repetir
# 1	Pessimamente
# 1	repetilohia
# 1	Bonitos
# 1	Bons
# 1	venerar
# 1	venerando
# 1	venerado
# 1	Pessoa
# 1	repercorreu
# 1	1
# 1	repentina
# 1	Petersburgo
# 1	Borgonha
# 1	Petits
# 1	repeliuo
# 1	repeliua
# 1	repeliu
# 1	repelira
# 1	Borrachos
# 1	Botelho
# 1	repatriado
# 1	repassavam
# 1	repassar
# 1	repassados
# 1	Aceito
# 1	repassadas
# 1	repassada
# 1	Peçolhe
# 1	Pieguice
# 1	repartida
# 1	Pigarreira
# 1	Pilatus
# 1	reparaste
# 1	Pingada
# 1	venderlhe
# 1	reparando
# 1	venderase
# 1	repagar
# 1	reorganizar
# 1	reocupou
# 1	venderam
# 1	renunciar
# 1	Pintado
# 1	Boulevard
# 1	Pinto
# 1	renovara
# 1	renovar
# 1	renovado
# 1	Aceitou
# 1	rendinha
# 1	rendimentos
# 1	Pirolito
# 1	rendilhado
# 1	Boulogne
# 1	rendida
# 1	Pirâmides
# 1	render
# 1	Pisara
# 1	Pit
# 1	20
# 1	renascesse
# 1	renascer
# 1	vendas
# 1	Planeamos
# 1	remoçava
# 1	remoçasse
# 1	Bourgogne
# 1	remoçada
# 1	Acendia
# 1	remotas
# 1	Bourgonhe
# 1	Planos
# 1	Planta
# 1	remontei
# 1	remontar
# 1	remontado
# 1	Platão
# 1	remoinhou
# 1	Boémia
# 1	remobilar
# 1	remobilada
# 1	remexiam
# 1	Plymouth
# 1	Ámen
# 1	vencera
# 1	Podemme
# 1	Podese
# 1	remeteuo
# 1	remeteu
# 1	remeterlhe
# 1	remetendolhe
# 1	Águeda
# 1	remeta
# 1	remessa
# 1	vencendo
# 1	remergulhava
# 1	remendos
# 1	rememorado
# 1	Podiase
# 1	rematando
# 1	vence
# 1	vemse
# 1	Poesia
# 1	relíquias
# 1	Polaco
# 1	relâmpagos
# 1	Pombal
# 1	Pombos
# 1	Pompadour
# 1	reluziulhe
# 1	reluziu
# 1	Aceso
# 1	Ponhalhe
# 1	Brandeburgo
# 1	Ponho
# 1	reluzentes
# 1	Ponte
# 1	religiões
# 1	Pontual
# 1	Brat
# 1	religioso
# 1	religiosidade
# 1	Poole
# 1	Brighton
# 1	Pope
# 1	Brilha
# 1	Popular
# 1	relevos
# 1	Porcalhota
# 1	releu
# 1	Poria
# 1	reler
# 1	Bristol
# 1	Português
# 1	Brota
# 1	relembra
# 1	Positivismo
# 1	relação
# 1	relaxação
# 1	Pote
# 1	relativas
# 1	relativamente
# 1	relanceou
# 1	relancearam
# 1	relanceara
# 1	relancear
# 1	Poulet
# 1	relambória
# 1	relambidos
# 1	relacionavamse
# 1	rejuvenescia
# 1	rejeitara
# 1	reitre
# 1	Poupame
# 1	velhinho
# 1	Pousado
# 1	reine
# 1	Brougton
# 1	Pousara
# 1	Pousou
# 1	regulavam
# 1	regulava
# 1	regulasse
# 1	regularmente
# 1	Brousse
# 1	reguapa
# 1	regressava
# 1	Brutalidade
# 1	regressado
# 1	Povo
# 1	Bucarini
# 1	regozijo
# 1	velavase
# 1	região
# 1	registos
# 1	registo
# 1	regimentos
# 1	regimento
# 1	Povos
# 1	Pratos
# 1	regeneradora
# 1	regenerador
# 1	regenera
# 1	regelavam
# 1	velavaa
# 1	regelados
# 1	regeladora
# 1	BudaPest
# 1	velar
# 1	regeladamente
# 1	Precisa
# 1	Precisavam
# 1	regatos
# 1	regato
# 1	regateei
# 1	regatas
# 1	regar
# 1	regantes
# 1	regando
# 1	regalouse
# 1	regalou
# 1	Precisávamos
# 1	regalase
# 1	regalar
# 1	regalado
# 1	Precursor
# 1	regador
# 1	regado
# 1	rega
# 1	refúgio
# 1	velador
# 1	refulgência
# 1	refulgiu
# 1	refulgiram
# 1	refulgiam
# 1	refulgia
# 1	velado
# 1	refulge
# 1	Preferia
# 1	refugiou
# 1	refugio
# 1	veladas
# 1	Preferiria
# 1	refugiara
# 1	refugiar
# 1	Preocupação
# 1	refugiados
# 1	refugiado
# 1	velada
# 1	refrescou
# 1	refresco
# 1	refrescavase
# 1	refrescava
# 1	Burke
# 1	refrescando
# 1	refrescado
# 1	refregas
# 1	vejoo
# 1	reforçaram
# 1	reforçado
# 1	vejome
# 1	Primeira
# 1	reflorescia
# 1	reflexões
# 1	Burocracia
# 1	Primeiramente
# 1	Principiei
# 1	Prior
# 1	Achandose
# 1	Proferia
# 1	Profeta
# 1	reflectidos
# 1	reflectido
# 1	Bélgica
# 1	reflechi
# 1	refinado
# 1	referência
# 1	referese
# 1	Bêbado
# 1	refazendo
# 1	reentrava
# 1	veiolhes
# 1	reentrando
# 1	reenchendo
# 1	reduziu
# 1	reduzir
# 1	reduzida
# 1	reduziase
# 1	Promete
# 1	Prometeralhe
# 1	Propaganda
# 1	redondinho
# 1	redondinha
# 1	Propriedade
# 1	redomoinhava
# 1	redominava
# 1	redoma
# 1	redijo
# 1	redigiu
# 1	redigirem
# 1	redigi
# 1	redige
# 1	BíbliaÉ
# 1	CANDIDO
# 1	Protectora
# 1	Prouvera
# 1	Provença
# 1	redacteur
# 1	CAPUCINES
# 1	recusoulha
# 1	Provençal
# 1	recuse
# 1	recusavalhe
# 1	CHAMBRE
# 1	recusarase
# 1	recusaram
# 1	recusar
# 1	recusandose
# 1	recusa
# 1	recurvo
# 1	vegetais
# 1	recursos
# 1	recurso
# 1	recuperares
# 1	recuperar
# 1	Publica
# 1	recubans
# 1	recuava
# 1	recuar
# 1	Publicalo
# 1	recuado
# 1	recto
# 1	rectificou
# 1	rectificar
# 1	rectificando
# 1	rectidão
# 1	Publicas
# 1	Publicou
# 1	recriminação
# 1	recriminar
# 1	recrimina
# 1	recrescialhe
# 1	recreio
# 1	recostouse
# 1	recostos
# 1	recostarse
# 1	recostados
# 1	Pues
# 1	Àquela
# 1	recortando
# 1	recortalas
# 1	Acharaa
# 1	Puis
# 1	recordou
# 1	recordo
# 1	Pulgas
# 1	Puxou
# 1	Páris
# 1	recordavam
# 1	Páscoas
# 1	recordarse
# 1	recordara
# 1	Pátria
# 1	Pâle
# 1	Pé
# 1	recordados
# 1	recontro
# 1	recontara
# 1	recontando
# 1	reconstruilo
# 1	veemente
# 1	vedes
# 1	zurzira
# 1	Pérsia
# 1	reconheci
# 1	CHRISTO
# 1	reconheceulhes
# 1	Péssimas
# 1	reconhecesse
# 1	reconhecerte
# 1	reconhecerse
# 1	COMMENDADOR
# 1	Pôs
# 1	reconhecelo
# 1	reconfortarse
# 1	reconfortar
# 1	reconfortando
# 1	reconfortalo
# 1	Pôsme
# 1	reconciliados
# 1	recompor
# 1	recompensados
# 1	Põete
# 1	recomeçavase
# 1	recomeçaram
# 1	Quatrocentos
# 1	recomeçar
# 1	Queirós
# 1	Cabrais
# 1	recomeça
# 1	recomendoulhe
# 1	vaya
# 1	recomendote
# 1	zumzum
# 1	Cafraria
# 1	recomendaralhe
# 1	recomendandolhe
# 1	recomendado
# 1	recomecei
# 1	Cai
# 1	recolhidos
# 1	Queixarase
# 1	recolhidas
# 1	Querianos
# 1	Caialhe
# 1	Queriao
# 1	recolhi
# 1	recolheuse
# 1	Querias
# 1	Queriate
# 1	Caiume
# 1	recolherem
# 1	recolheramse
# 1	Querma
# 1	recolheraa
# 1	recolhera
# 1	Querolhe
# 1	Calabria
# 1	Querome
# 1	recoberto
# 1	Quimera
# 1	Calado
# 1	reclusa
# 1	reclinandose
# 1	reclinado
# 1	reclinada
# 1	Quimper
# 1	reclamo
# 1	reclamações
# 1	reclamavao
# 1	Calamse
# 1	reclamasse
# 1	vasando
# 1	reclamar
# 1	reclamados
# 1	recivilizado
# 1	recitou
# 1	recitavaos
# 1	recitavam
# 1	recitava
# 1	zumbir
# 1	recitas
# 1	Quinta
# 1	recitando
# 1	zombarias
# 1	reciprocando
# 1	recipe
# 1	Quinto
# 1	Calate
# 1	rechonchudos
# 1	rechonchuda
# 1	recheio
# 1	Quinze
# 1	varriase
# 1	receitas
# 1	varriam
# 1	receitando
# 1	Quiseram
# 1	RAPPEL
# 1	receia
# 1	recebo
# 1	varreu
# 1	RR
# 1	Rabelais
# 1	Racaqué
# 1	recebeulhe
# 1	Rachelsinha
# 1	receberem
# 1	receberao
# 1	receberam
# 1	Rafael
# 1	Rainha
# 1	Ramalhão
# 1	recebemos
# 1	recebem
# 1	Randon
# 1	receba
# 1	receavam
# 1	Raquel
# 1	recear
# 1	Raquesinha
# 1	recaíram
# 1	recaíra
# 1	Calatrava
# 1	recatadas
# 1	varrendo
# 1	recantosinho
# 1	Raras
# 1	Rasgou
# 1	recambiada
# 1	varou
# 1	recamada
# 1	varinos
# 1	varinas
# 1	varina
# 1	recair
# 1	recaindo
# 1	recaialhe
# 1	recaia
# 1	Rasparse
# 1	Rato
# 1	rebuço
# 1	rebuçados
# 1	rebuscava
# 1	rebuscar
# 1	rebuscando
# 1	variedades
# 1	variedade
# 1	rebrilhou
# 1	Razões
# 1	Realeza
# 1	Calcutá
# 1	rebrilhando
# 1	Recados
# 1	rebolandose
# 1	rebolando
# 1	rebocado
# 1	rebocada
# 1	rebentões
# 1	rebentou
# 1	rebente
# 1	Receais
# 1	Acharam
# 1	rebentando
# 1	rebentamos
# 1	rebentada
# 1	Recebemos
# 1	rebelde
# 1	zeloso
# 1	varandoo
# 1	rebates
# 1	rebate
# 1	rebanho
# 1	rebaixamento
# 1	reatando
# 1	reassumiu
# 1	reaparição
# 1	varandinha
# 1	Reclame
# 1	reaparecesse
# 1	Calderon
# 1	reaparecendo
# 1	Caldilo
# 1	reanimou
# 1	reanimavase
# 1	realçava
# 1	zelosamente
# 1	Recolha
# 1	realizável
# 1	realizáveis
# 1	realização
# 1	realizava
# 1	realizara
# 1	Recolhendo
# 1	realizando
# 1	realizadas
# 1	Recolheram
# 1	Reconhecera
# 1	Reconheceua
# 1	Reconhecia
# 1	Recuai
# 1	Recuperara
# 1	reagiu
# 1	reagir
# 1	readormecer
# 1	reaccionário
# 1	reabotoou
# ...
# 14	seguia
# 14	reino
# 14	imbecil
# 15	recomeçou
# 15	confessou
# 15	compreender
# 15	escadas
# 15	perfume
# 15	neve
# 15	podiam
# 15	erguera
# 15	punha
# 15	saias
# 15	culpa
# 15	fila
# 15	saltou
# 15	portuguesa
# 15	abaixo
# 15	cerimónia
# 15	vinte
# 15	banco
# 15	conheço
# 15	sentarse
# 15	receber
# 15	Vargas
# 15	pensativo
# 15	tornou
# 15	ramagens
# 15	achou
# 15	pendia
# 15	John
# 15	examinar
# 15	peliça
# 15	coitado
# 15	findar
# 15	sós
# 15	versos
# 15	dogcart
# 15	pedir
# 15	quinze
# 15	Apolónia
# 15	perna
# 15	passavam
# 15	crianças
# 15	sorrir
# 15	imóvel
# 15	cómoda
# 15	imenso
# 15	divino
# 15	permanecia
# 15	sabes
# 15	daqui
# 15	bicos
# 15	severo
# 15	teatro
# 15	som
# 15	viesse
# 15	ideal
# 15	valer
# 15	bolsos
# 15	Nova
# 15	seca
# 15	companhia
# 15	casaco
# 15	Nos
# 15	abria
# 15	italiano
# 15	meter
# 15	digno
# 15	tédio
# 15	crise
# 15	profundamente
# 15	botão
# 15	trazer
# 15	diga
# 15	perguntava
# 15	Concha
# 15	caramba
# 15	Democracia
# 15	Figaro
# 15	haver
# 15	candeeiro
# 15	Silveira
# 15	obra
# 15	canalha
# 15	educação
# 15	tristes
# 15	névoa
# 15	nuvens
# 15	gola
# 15	novos
# 15	nove
# 15	guardanapo
# 15	guarda
# 15	laboratório
# 15	nomes
# 15	alegres
# 15	muros
# 15	vidros
# 16	dominó
# 16	ama
# 16	tecto
# 16	admiração
# 16	conservava
# 16	chaminé
# 16	primeiros
# 16	Nunes
# 16	roda
# 16	maneiras
# 16	parar
# 16	levou
# 16	Minhoto
# 16	ultimamente
# 16	rodas
# 16	par
# 16	mar
# 16	Numa
# 16	assombrado
# 16	procurando
# 16	leu
# 16	massa
# 16	languidamente
# 16	cheios
# 16	pesados
# 16	vinho
# 16	cachenez
# 16	erguer
# 16	descer
# 16	abafado
# 16	soltou
# 16	subitamente
# 16	fumando
# 16	detalhes
# 16	Queria
# 16	banal
# 16	recanto
# 16	abalou
# 16	famoso
# 16	vais
# 16	Ás
# 16	poesia
# 16	recolher
# 16	comboio
# 16	aparecer
# 16	coroa
# 16	histórias
# 16	caridade
# 16	gota
# 16	falara
# 16	Havaneza
# 16	etc
# 16	tremulo
# 16	pó
# 16	hesitou
# 16	descobriu
# 16	negras
# 16	erguerase
# 16	suave
# 16	estacou
# 16	indignação
# 16	rir
# 16	morta
# 16	documento
# 16	passear
# 16	morto
# 16	embrulhado
# 16	caído
# 16	tive
# 16	Brasil
# 16	quintal
# 16	embora
# 16	espada
# 16	linhas
# 16	tolice
# 16	últimos
# 16	vaga
# 16	Aquilo
# 16	partido
# 16	voltara
# 16	espanto
# 16	reis
# 16	artista
# 16	aldeia
# 16	Sitiais
# 16	pálida
# 16	jamais
# 16	Desde
# 16	limpando
# 16	conhecera
# 16	Craveiro
# 16	Caramba
# 16	silenciosa
# 17	delicioso
# 17	dormente
# 17	social
# 17	mostrando
# 17	ultima
# 17	Durante
# 17	Europa
# 17	gravemente
# 17	pista
# 17	beira
# 17	decidido
# 17	interior
# 17	acima
# 17	genebra
# 17	estudo
# 17	Vou
# 17	Do
# 17	cantos
# 17	motivo
# 17	regaço
# 17	fidalgo
# 17	procurar
# 17	Nessa
# 17	melhores
# 17	sete
# 17	cálice
# 17	mostrava
# 17	Rughel
# 17	mentira
# 17	campainha
# 17	borda
# 17	génio
# 17	certa
# 17	réis
# 17	ouvido
# 17	esposa
# 17	convento
# 17	Dois
# 17	vasto
# 17	alívio
# 17	sequer
# 17	cofre
# 17	luzes
# 17	dignidade
# 17	grupo
# 17	influência
# 17	coberta
# 17	fome
# 17	buscar
# 17	ciência
# 17	muro
# 17	deste
# 17	Senhor
# 17	madrugada
# 17	Ana
# 17	conversando
# 17	progresso
# 17	patamar
# 17	frases
# 17	inquieto
# 17	canapé
# 17	nenhuma
# 17	pergunta
# 17	Alvim
# 17	Luís
# 17	desejava
# 17	obras
# 17	curta
# 17	pediu
# 17	vive
# 17	Essa
# 17	deusa
# 17	nela
# 17	indo
# 18	murmurar
# 18	perto
# 18	vale
# 18	Vila
# 18	acabouse
# 18	pernas
# 18	consigo
# 18	praça
# 18	Capítulo
# 18	pensar
# 18	Carlinhos
# 18	Vai
# 18	vagar
# 18	vagamente
# 18	facto
# 18	Renascença
# 18	jaquetão
# 18	fortuna
# 18	raça
# 18	cuidado
# 18	frescura
# 18	parara
# 18	parando
# 18	s
# 18	ouvira
# 18	furiosamente
# 18	Teve
# 18	Bonifácio
# 18	fato
# 18	soirée
# 18	ninho
# 18	vê
# 18	desgraça
# 18	negócios
# 18	punhos
# 18	solidão
# 18	Gouvarinhos
# 18	conversar
# 18	murmúrio
# 18	murmurava
# 18	tomava
# 18	pátio
# 18	destas
# 18	muda
# 18	anda
# 18	brutal
# 18	Quer
# 18	morreu
# 18	esteve
# 18	anjo
# 18	coberto
# 18	vermelha
# 18	enternecido
# 18	houvesse
# 18	àquele
# 18	intolerável
# 18	querer
# 18	impressão
# 18	longas
# 18	livre
# 18	cozinha
# 18	curto
# 18	tipo
# 18	ler
# 18	ódio
# 18	portas
# 18	tirar
# 18	chegara
# 18	pontas
# 18	esplêndido
# 18	poderia
# 18	posso
# 18	esquina
# 18	salas
# 19	Cliford
# 19	Ninguém
# 19	orgulho
# 19	mole
# 19	começava
# 19	fácil
# 19	Diabo
# 19	santo
# 19	bairro
# 19	Olhe
# 19	rei
# 19	dado
# 19	elas
# 19	dizendo
# 19	Vá
# 19	acácias
# 19	adeus
# 19	paredes
# 19	lindos
# 19	curioso
# 19	madame
# 19	pudesse
# 19	Ali
# 19	Jesus
# 19	vasta
# 19	batia
# 19	gostava
# 19	rendas
# 19	davam
# 19	Lawrence
# 19	subir
# 19	bilhetes
# 19	cigarrete
# 19	Aquele
# 19	sublime
# 19	apertando
# 19	amores
# 19	viscondessa
# 19	ardente
# 19	espanholas
# 19	très
# 19	boas
# 19	fogão
# 19	plano
# 19	tranquilamente
# 19	nesses
# 19	escândalo
# 19	adorável
# 19	vestidos
# 19	passeio
# 19	creio
# 19	ternura
# 19	levando
# 19	palmas
# 19	corria
# 19	morria
# 19	perguntar
# 19	morrera
# 19	coragem
# 19	tirando
# 19	governante
# 19	bons
# 19	Dize
# 19	brilhante
# 19	erguendo
# 19	desgraçado
# 19	Todo
# 19	índia
# 19	cruz
# 19	outono
# 19	caiu
# 20	lentos
# 20	sujeitos
# 20	moral
# 20	cigarro
# 20	caminho
# 20	calados
# 20	comovido
# 20	reles
# 20	chorar
# 20	memória
# 20	perdido
# 20	esplendor
# 20	acha
# 20	polícia
# 20	ultimo
# 20	ponto
# 20	chegava
# 20	fria
# 20	águas
# 20	deviam
# 20	Sempre
# 20	administrador
# 20	frisa
# 20	própria
# 20	Gambeta
# 20	champagne
# 20	imaginação
# 20	soube
# 20	Finlândia
# 20	toilete
# 20	casar
# 20	bruscamente
# 20	fugiu
# 20	ruas
# 20	carruagens
# 20	desesperado
# 20	vivamente
# 20	banho
# 20	ocasião
# 20	experiência
# 20	sorte
# 20	entusiasmo
# 20	tremia
# 20	muitas
# 20	tremer
# 20	Sem
# 20	almofada
# 20	ambas
# 20	lembrava
# 20	estendeu
# 20	ingleses
# 20	chegar
# 21	Onde
# 21	tantas
# 21	acabava
# 21	pensou
# 21	natural
# 21	Vladimiro
# 21	amável
# 21	dentes
# 21	fina
# 21	vindo
# 21	poder
# 21	terror
# 21	caro
# 21	ontem
# 21	vontade
# 21	Qual
# 21	profundo
# 21	digo
# 21	correndo
# 21	Esse
# 21	filhos
# 21	sorriu
# 21	reps
# 21	erguendose
# 21	ares
# 21	preta
# 21	Brown
# 21	besta
# 21	pessoas
# 21	belos
# 21	lunetas
# 21	vergonha
# 21	aberto
# 21	cavalheiros
# 21	velas
# 21	fortes
# 21	espanhola
# 21	relações
# 22	superior
# 22	fossem
# 22	tristeza
# 22	nesta
# 22	perfeitamente
# 22	casas
# 22	colete
# 22	prata
# 22	idade
# 22	charutos
# 22	break
# 22	principio
# 22	verniz
# 22	estão
# 22	deixava
# 22	faziam
# 22	fugir
# 22	mangas
# 22	seio
# 22	feliz
# 22	senso
# 22	ramo
# 22	domingo
# 22	vista
# 22	titi
# 22	retrato
# 22	viva
# 22	encontro
# 22	procurava
# 22	excelente
# 22	levava
# 22	querido
# 22	Aquela
# 22	riso
# 22	abertas
# 22	contente
# 22	pesado
# 22	nossa
# 22	dever
# 22	desgosto
# 22	renda
# 22	voltava
# 22	falta
# 22	único
# 22	bêbedo
# 22	semana
# 22	vá
# 22	ora
# 22	brasileira
# 23	estilo
# 23	roupa
# 23	houve
# 23	Sousa
# 23	Toda
# 23	França
# 23	Este
# 23	padre
# 23	menina
# 23	cavalheiro
# 23	estás
# 23	terrível
# 23	cansado
# 23	sentiu
# 23	cadelinha
# 23	nariz
# 23	passeando
# 23	Charlie
# 23	mostrar
# 23	moço
# 23	abertos
# 23	Coimbra
# 23	desceu
# 23	sentado
# 23	todavia
# 23	descia
# 23	príncipe
# 23	móveis
# 23	la
# 23	cadeiras
# 23	amiga
# 23	deles
# 23	pareciam
# 23	consultório
# 23	deliciosa
# 23	certeza
# 23	Justamente
# 23	folha
# 23	vestida
# 23	divã
# 23	feita
# 23	conhece
# 23	natureza
# 23	relva
# 23	pensando
# 23	sombrio
# 23	começo
# 23	cachimbo
# 23	Estou
# 23	perder
# 23	dormia
# 23	sapatos
# 23	largamente
# 23	brancos
# 23	voltandose
# 23	horrível
# 23	ramos
# 23	qual
# 23	prato
# 24	folhas
# 24	vão
# 24	gentleman
# 24	Tens
# 24	baronesa
# 24	olhava
# 24	tanta
# 24	adiante
# 24	exemplo
# 24	emoção
# 24	têm
# 24	abrir
# 24	passara
# 24	extraordinário
# 24	tomou
# 24	outrora
# 24	ouvir
# 24	sentindo
# 24	meus
# 24	manhãs
# 24	Mr
# 24	português
# 24	movimento
# 24	continuou
# 24	dissera
# 24	Nós
# 24	acabar
# 24	querendo
# 24	ria
# 24	Cunha
# 24	esperança
# 24	Mais
# 24	dormir
# 24	gordo
# 24	figura
# 24	civilização
# 24	comigo
# 24	barbas
# 24	rosnou
# 24	Apenas
# 24	mau
# 25	dá
# 25	olhou
# 25	nisso
# 25	Champagne
# 25	correr
# 25	boca
# 25	prazer
# 25	clara
# 25	pensava
# 25	vamos
# 25	sentir
# 25	Neves
# 25	saúde
# 25	São
# 25	escrever
# 25	degraus
# 25	frase
# 25	saia
# 25	intimidade
# 25	propósito
# 25	alegre
# 25	antecâmara
# 25	bigode
# 25	criada
# 25	partiu
# 25	rapariga
# 25	juntos
# 25	pele
# 25	deixando
# 25	Ia
# 25	doçura
# 25	gravata
# 25	Teixeira
# 25	és
# 25	atirando
# 25	velhos
# 26	Talvez
# 26	abriu
# 26	salão
# 26	próprio
# 26	claridade
# 26	neto
# 26	aberta
# 26	teria
# 26	Sta
# 26	àquela
# 26	depressa
# 26	atirou
# 26	pior
# 26	pôr
# 26	Ó
# 26	lembrou
# 26	Nada
# 26	caixa
# 26	bonita
# 26	subiu
# 26	Gazeta
# 26	lenta
# 26	vivia
# 26	armas
# 26	Gama
# 26	queres
# 26	parecialhe
# 26	arranjar
# 26	real
# 26	bengala
# 26	sarau
# 26	chávena
# 26	Arroios
# 26	literatura
# 26	conhecer
# 26	bateu
# 26	espelho
# 26	curiosidade
# 27	mandar
# 27	noites
# 27	véu
# 27	tons
# 27	Lá
# 27	alcova
# 27	destes
# 27	fizera
# 27	antiga
# 27	fino
# 27	bordado
# 27	Todos
# 27	quartos
# 27	possível
# 27	ti
# 27	risonho
# 27	Balzac
# 27	chamar
# 27	tivera
# 27	lho
# 27	Revista
# 27	Darque
# 27	letras
# 27	Eram
# 27	esperar
# 27	lados
# 27	alta
# 27	negros
# 27	esquecido
# 27	negra
# 27	naturalmente
# 27	neste
# 27	vento
# 28	linha
# 28	belas
# 28	fresco
# 28	ficaram
# 28	bilhete
# 28	vivo
# 28	chama
# 28	debaixo
# 28	maneira
# 28	esforço
# 28	Euzébio
# 28	bonito
# 28	direito
# 28	nervoso
# 28	estivera
# 28	sociedade
# 28	Tenho
# 28	alguém
# 28	deixara
# 28	rosas
# 28	foram
# 28	segredo
# 28	forma
# 29	espírito
# 29	bastante
# 29	gás
# 29	visita
# 29	criatura
# 29	iam
# 29	música
# 29	balbuciou
# 29	única
# 29	sentimento
# 29	Benfica
# 29	garrafa
# 29	quê
# 29	monóculo
# 29	existência
# 29	rompeu
# 29	copo
# 29	longos
# 29	ponta
# 29	lume
# 29	desta
# 29	rica
# 29	viagem
# 29	política
# 29	andava
# 29	cidade
# 29	sido
# 29	fazendo
# 29	acaso
# 30	chamava
# 30	enorme
# 30	batendo
# 30	sou
# 30	respeito
# 30	alegremente
# 30	estado
# 30	impaciente
# 30	caleche
# 30	letra
# 30	Rufino
# 30	século
# 30	visto
# 30	brancas
# 30	sujeito
# 30	lugar
# 30	Neto
# 30	interesse
# 30	entrava
# 30	aroma
# 30	terminou
# 30	médico
# 30	dera
# 31	disselhe
# 31	Rachel
# 31	qualquer
# 31	Inglaterra
# 31	simplesmente
# 31	ordem
# 31	almoço
# 31	morte
# 31	apesar
# 31	luto
# 31	lhes
# 31	torno
# 31	exclamava
# 31	bater
# 31	beijos
# 31	bigodes
# 31	hei
# 31	graça
# 31	cara
# 31	furioso
# 31	talento
# 31	chegou
# 31	Além
# 31	chuva
# 31	chá
# 31	estes
# 31	cognac
# 32	voltouse
# 32	abade
# 32	pessoa
# 32	algumas
# 32	Á
# 32	jornais
# 32	deixou
# 32	morrer
# 32	ano
# 32	antigo
# 32	ombro
# 32	aparecia
# 32	ministro
# 32	leque
# 32	Olha
# 32	corpo
# 32	seis
# 32	melancolia
# 32	seja
# 32	Nesse
# 32	viver
# 32	pôde
# 32	bilhar
# 32	quente
# 33	Havia
# 33	tomar
# 33	cedo
# 33	deve
# 33	testa
# 33	cocheiro
# 33	Central
# 33	escudeiro
# 33	fresca
# 33	gabinete
# 33	Diogo
# 33	Teles
# 33	partir
# 33	senhores
# 33	ía
# 33	maior
# 33	cólera
# 33	camisa
# 33	contou
# 33	campo
# 33	dessas
# 33	Dr
# 33	libras
# 33	amizade
# 34	Sequeira
# 34	amante
# 34	Esta
# 34	Celorico
# 34	continuava
# 34	alegria
# 34	muita
# 34	ai
# 34	Tem
# 34	temos
# 34	séria
# 34	portinhola
# 34	olhando
# 35	nele
# 35	Estava
# 35	levar
# 35	Nunca
# 35	colo
# 35	força
# 35	falou
# 35	quer
# 35	tua
# 35	tribuna
# 35	declarou
# 35	quero
# 35	brilho
# 36	MacGren
# 36	Itália
# 36	tio
# 36	Salcede
# 36	trabalho
# 36	diz
# 36	passando
# 36	acrescentou
# 36	escritório
# 36	Muito
# 36	Cohens
# 36	seguinte
# 36	Vamos
# 36	saiu
# 36	Chiado
# 37	surpresa
# 37	acudiu
# 37	Aqui
# 37	hotel
# 37	cavalo
# 37	escuro
# 37	radiante
# 37	medo
# 37	pois
# 37	aquelas
# 37	suspiro
# 37	entrou
# 37	nova
# 37	irmã
# 37	justamente
# 37	cinco
# 37	rio
# 37	segundo
# 37	papá
# 37	íntimo
# 37	dez
# 37	cair
# 37	Maias
# 37	ergueu
# 37	ferro
# 37	questão
# 38	artigo
# 38	ficar
# 38	pareceu
# 38	dessa
# 38	pedra
# 38	tal
# 38	modo
# 38	cetim
# 38	miss
# 38	barba
# 38	lindo
# 38	dito
# 39	longo
# 39	romance
# 39	teu
# 39	Corneta
# 39	parou
# 39	Hotel
# 39	Isso
# 39	atrás
# 39	andar
# 39	deixar
# 39	viu
# 39	frio
# 39	festa
# 39	criança
# 39	escada
# 39	casaca
# 39	doente
# 39	longa
# 40	Londres
# 40	beijo
# 40	cartas
# 40	felicidade
# 40	mármore
# 40	jornal
# 40	desses
# 40	defronte
# 40	tempos
# 40	Grémio
# 40	vermelho
# 40	nobre
# 40	voltar
# 40	Até
# 40	contar
# 40	mudo
# 40	livros
# 40	Assim
# 41	durante
# 41	entrar
# 41	vago
# 41	escarlate
# 41	encolheu
# 41	beleza
# 41	naquele
# 41	paz
# 41	luvas
# 41	sair
# 41	espera
# 41	Niniche
# 41	Melanie
# 41	encanto
# 41	mulheres
# 41	pressa
# 41	Aí
# 41	criados
# 41	rosto
# 42	inglês
# 42	Nem
# 42	carruagem
# 42	Aterro
# 42	rico
# 42	estrada
# 42	semanas
# 42	voltou
# 42	esperava
# 42	parece
# 43	sobretudo
# 43	Madame
# 43	portão
# 43	costas
# 43	umas
# 43	parte
# 43	passo
# 43	terraço
# 43	terra
# 43	falando
# 43	café
# 44	sobrecasaca
# 44	arte
# 44	verde
# 44	hein
# 44	falava
# 44	larga
# 44	Fora
# 44	senão
# 44	tivesse
# 44	Só
# 44	Sarah
# 44	causa
# 44	vendo
# 44	tapete
# 45	pena
# 45	correu
# 45	céu
# 45	sorria
# 45	desse
# 45	verão
# 45	chão
# 45	meses
# 45	vem
# 45	amanhã
# 45	Porto
# 45	Domingos
# 45	passava
# 45	relógio
# 45	conhecia
# 46	sim
# 46	Porque
# 46	Bem
# 46	cheia
# 46	Você
# 46	procurador
# 46	tendo
# 46	ficava
# 46	cama
# 47	lento
# 47	uns
# 47	dor
# 47	negro
# 47	honra
# 47	linda
# 47	trazia
# 47	aqueles
# 47	essas
# 47	ficara
# 47	pode
# 48	pescoço
# 48	Há
# 48	sentia
# 48	marido
# 48	pálido
# 48	esses
# 48	inglesa
# 48	achava
# 48	cabelo
# 48	gesto
# 49	ergueuse
# 49	chic
# 49	partida
# 49	piano
# 49	Quem
# 49	mil
# 49	estou
# 49	traz
# 49	encontrar
# 49	redor
# 49	seria
# 50	vira
# 50	vou
# 50	viera
# 50	Toca
# 50	reposteiro
# 50	decerto
# 50	quatro
# 50	tanto
# 50	cabelos
# 50	meia
# 51	passou
# 51	porém
# 51	volta
# 51	algum
# 51	horror
# 51	flor
# 51	hoje
# 52	joelhos
# 52	ideias
# 52	João
# 52	sério
# 52	corridas
# 52	vocês
# 52	lenço
# 52	daquele
# 52	dava
# 52	Ainda
# 52	senhoras
# 52	lábios
# 53	sombra
# 53	começou
# 53	paletó
# 53	janelas
# 53	doce
# 53	vestido
# 53	passado
# 53	calor
# 54	As
# 54	estar
# 54	faz
# 54	rapazes
# 54	Está
# 54	naquela
# 54	bocado
# 54	outras
# 55	Eusebiozinho
# 55	menos
# 55	desejo
# 55	pequeno
# 55	cheio
# 55	primeira
# 55	papéis
# 55	sabe
# 55	simples
# 55	história
# 55	aquilo
# 55	rumor
# 55	homens
# 55	imediatamente
# 56	rosa
# 56	mesma
# 56	via
# 56	tipóia
# 56	tens
# 56	Tinha
# 56	quis
# 57	Exª
# 57	sangue
# 57	veludo
# 57	rindo
# 57	Agora
# 57	ambos
# 58	véspera
# 58	além
# 58	estas
# 58	disso
# 58	poltrona
# 58	grave
# 58	árvores
# 58	belo
# 58	lágrimas
# 58	jardim
# 59	inverno
# 59	realmente
# 59	feito
# 59	vai
# 60	pequena
# 60	cavalos
# 60	quanto
# 60	dando
# 60	nós
# 61	respondeu
# 61	leito
# 61	devagar
# 61	Ora
# 61	dinheiro
# 61	Portugal
# 61	Palma
# 62	Tudo
# 62	Steinbroken
# 62	alguns
# 62	peito
# 64	luxo
# 64	corredor
# 64	tom
# 65	maestro
# 65	família
# 65	gosto
# 65	coupé
# 66	Francisco
# 66	lentamente
# 66	janela
# 66	apareceu
# 66	Olivais
# 67	preto
# 67	boa
# 67	palavra
# 67	pés
# 67	caso
# 67	triste
# 67	razão
# 68	nosso
# 68	paixão
# 68	sorriso
# 68	cada
# 68	dedos
# 68	hora
# 69	Na
# 69	passar
# 69	daquela
# 69	Monforte
# 69	olho
# 69	seda
# 70	estavam
# 70	ninguém
# 70	si
# 70	entanto
# 71	longe
# 71	água
# 71	fez
# 71	sorrindo
# 71	contra
# 72	leve
# 72	largo
# 72	enquanto
# 72	país
# 72	antes
# 72	filha
# 73	passos
# 73	Tu
# 73	cadeira
# 73	vir
# 73	certo
# 73	pelas
# 74	mim
# 75	livro
# 75	meio
# 75	branca
# 76	velha
# 76	Deus
# 76	gritou
# 76	flores
# 76	nesse
# 76	bela
# 77	Como
# 77	branco
# 77	menino
# 77	sei
# 77	poeta
# 77	charuto
# 78	Com
# 78	Srª
# 80	através
# 80	Ah
# 81	outros
# 81	ouro
# 81	alguma
# 81	grandes
# 81	deu
# 81	fazia
# 81	daí
# 81	papel
# 82	melhor
# 82	claro
# 82	forte
# 83	Taveira
# 83	nessa
# 83	primeiro
# 84	eles
# 84	Para
# 84	quinta
# 84	criado
# 85	são
# 85	mamã
# 85	Isto
# 85	tenho
# 85	diabo
# 85	mundo
# 86	azul
# 86	alma
# 86	sofá
# 86	Rosa
# 87	Baptista
# 88	filho
# 88	devia
# 89	talvez
# 89	palavras
# 89	Enfim
# 89	canto
# 90	instante
# 90	pelos
# 91	Se
# 91	resto
# 93	Castro
# 93	Ao
# 93	você
# 94	Guimarães
# 94	ombros
# 95	efeito
# 95	pai
# 97	sabia
# 98	eram
# 98	veio
# 99	Foi
# 99	perguntou
# 99	mãe
# 99	cima
# 100	vinha
# 100	mal
# 100	dar
# 101	cá
# 101	alto
# 102	parecia
# 102	teve
# 102	enfim
# 102	senhor
# 102	fosse
# 102	novo
# 102	podia
# 102	pobre
# 103	conde
# 103	rapaz
# 104	queria
# 104	sol
# 104	Gomes
# 105	ideia
# 105	Oh
# 105	necessário
# 106	Sintra
# 106	Santa
# 106	Olavia
# 107	Por
# 107	Já
# 108	saber
# 108	braço
# 108	este
# 109	horas
# 109	falar
# 109	junto
# 109	Cohen
# 109	Quando
# 110	luz
# 112	ficou
# 112	nome
# 113	S
# 113	verdade
# 113	amigos
# 114	gente
# 115	todas
# 115	bom
# 115	Paris
# 115	cor
# 116	Em
# 116	carta
# 117	manhã
# 119	três
# 119	cabeça
# 119	nunca
# 119	No
# 120	desde
# 121	Sim
# 123	Eduarda
# 124	minha
# 124	porque
# 125	anos
# 125	Gouvarinho
# 125	Os
# 127	dele
# 128	Uma
# 129	Pedro
# 130	Pois
# 130	repente
# 131	Ele
# 132	coração
# 132	jantar
# 133	vezes
# 133	Excª
# 134	amor
# 134	baixo
# 135	dizer
# 136	tarde
# 137	dentro
# 137	voz
# 138	olhar
# 138	fundo
# 142	chapéu
# 142	aí
# 144	condessa
# 145	De
# 145	tempo
# 146	te
# 146	dias
# 150	tinham
# 150	silêncio
# 151	vida
# 151	dela
# 152	face
# 152	fim
# 155	pé
# 156	avô
# 157	murmurou
# 157	amigo
# 158	sob
# 158	quem
# 159	aqui
# 159	Ela
# 159	rua
# 159	marquês
# 160	ir
# 163	apenas
# 163	quasi
# 164	aquela
# 165	Um
# 165	todos
# 166	isto
# 166	fazer
# 166	suas
# 166	braços
# 167	diante
# 168	isso
# 168	esta
# 169	nas
# 170	Ramalhete
# 171	quarto
# 172	vez
# 177	Cruges
# 177	esse
# 179	D
# 180	aquele
# 180	mulher
# 180	nada
# 181	tem
# 182	dizia
# 183	está
# 188	ver
# 189	ter
# 189	ia
# 190	porta
# 192	coisas
# 193	V
# 194	exclamou
# 195	Lisboa
# 195	pouco
# 195	velho
# 195	momento
# 200	dia
# 200	sala
# 202	mesa
# 203	mãos
# 204	Alencar
# 204	Eu
# 206	tu
# 206	coisa
# 208	essa
# 209	outra
# 210	nem
# 211	há
# 214	senhora
# 214	duma
# 214	meu
# 220	noite
# 221	aos
# 221	ás
# 222	até
# 223	lado
# 224	duas
# 226	ser
# 227	assim
# 233	fora
# 239	Craft
# 240	homem
# 244	dois
# 245	havia
# 247	Era
# 248	ar
# 252	mesmo
# 254	Então
# 255	ou
# 259	outro
# 261	Depois
# 268	toda
# 269	Maia
# 269	então
# 269	mão
# 269	sempre
# 273	pelo
# 273	ali
# 280	mas
# 281	me
# 283	foi
# 283	pela
# 294	Que
# 295	todo
# 301	depois
# 302	só
# 303	logo
# 308	agora
# 309	Vilaça
# 314	casa
# 318	bem
# 319	também
# 320	Afonso
# 324	nos
# 324	dum
# 324	grande
# 328	entre
# 328	quando
# 328	tudo
# 331	estava
# 335	olhos
# 342	disse
# 351	Sr
# 353	seus
# 354	É
# 355	tão
# 364	onde
# 364	numa
# 381	ainda
# 382	eu
# 385	tinha
# 396	Dâmaso
# 402	sem
# 408	num
# 439	Maria
# 452	lá
# 467	sobre
# 472	A
# 474	das
# 508	Não
# 558	muito
# 564	já
# 581	ela
# 620	dos
# 671	lhe
# 680	Mas
# 723	era
# 765	sua
# 774	mais
# 882	seu
# 891	à
# 930	O
# 942	é
# 945	ele
# 961	por
# 1045	como
# 1125	Ega
# 1251	na
# 1394	ao
# 1401	as
# 1436	se
# 1441	no
# 1510	em
# 1661	não
# 1697	E
# 1737	para
# 1763	os
# 1797	Carlos
# 2170	uma
# 2202	da
# 2571	do
# 2794	com
# 3026	um
# 4533	e
# 4986	que
# 6615	o
# 6736	a
# 8311	de
